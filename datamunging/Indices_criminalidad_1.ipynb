# %% [markdown]
# ## ARBIL 2024.

# %%
import pandas as pd

# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Abril 2024/DATOS EN FORMATO REUTILIZABLE ABRIL 2024.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# %%
# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# %%
# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             25                              87
# 1  ARGANZUELA                              6                               6
# 2      RETIRO                              0                               3
# 3   SALAMANCA                             10                              47
# 4   CHAMARTÍN                              6                              12
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                      4                     123                      9
# 1                      1                      20                      3
# 2                      0                       3                      1
# 3                      1                      22                      1
# 4                      0                      56                     16
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                149
# 1  ARGANZUELA                                 28
# 2      RETIRO                                 12
# 3   SALAMANCA                                 61
# 4   CHAMARTÍN                                 21
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            60            58
# 1  ARGANZUELA            28            62
# 2      RETIRO            48            59
# 3   SALAMANCA            52            56
# 4   CHAMARTÍN            72            81
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO           57
# 1  ARGANZUELA           18
# 2      RETIRO           12
# 3   SALAMANCA           29
# 4   CHAMARTÍN           12
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                 119                         25
# 1  ARGANZUELA                                  11                          4
# 2      RETIRO                                  22                          8
# 3   SALAMANCA                                   0                          2
# 4   CHAMARTÍN                                  28                         28
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                      13                               11
# 1  ARGANZUELA                       0                                9
# 2      RETIRO                       4                               27
# 3   SALAMANCA                       5                               12
# 4   CHAMARTÍN                      13                               37

# %%
# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Abril 2024/{hoja.lower().replace(" ", "_")}.csv', index=False)

# %% [markdown]
# ## MARZO 2024

# %%
import pandas as pd

# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Marzo 2024/DATOS EN FORMATO REUTILIZABLE MARZO 2024.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")

# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Marzo 2024/{hoja.lower().replace(" ", "_")}.csv', index=False)
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             24                             120
# 1  ARGANZUELA                              4                               5
# 2      RETIRO                              4                               2
# 3   SALAMANCA                              4                              45
# 4   CHAMARTÍN                              5                              13
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                      4                     311                     30
# 1                      3                       8                      5
# 2                      2                       1                      2
# 3                      2                       8                      0
# 4                      1                      46                     62
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                165
# 1  ARGANZUELA                                 21
# 2      RETIRO                                  7
# 3   SALAMANCA                                 63
# 4   CHAMARTÍN                                 28
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            47            67
# 1  ARGANZUELA            31            58
# 2      RETIRO            28            45
# 3   SALAMANCA            50            62
# 4   CHAMARTÍN            56            71
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO           41
# 1  ARGANZUELA           16
# 2      RETIRO            4
# 3   SALAMANCA           18
# 4   CHAMARTÍN           10
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                 155                         24
# 1  ARGANZUELA                                   9                          3
# 2      RETIRO                                  19                          9
# 3   SALAMANCA                                   1                          0
# 4   CHAMARTÍN                                  36                         49
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                      29                                5
# 1  ARGANZUELA                       1                                7
# 2      RETIRO                       5                               17
# 3   SALAMANCA                       0                                5
# 4   CHAMARTÍN                       0                               29

# %% [markdown]
# ## FEBRERO 2024.

# %%
import pandas as pd

# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Febrero 2024/DATOS EN FORMATO REUTILIZABLE FEBRERO 2024.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")

# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Febrero 2024/{hoja.lower().replace(" ", "_")}.csv', index=False)
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             29                             112
# 1  ARGANZUELA                              7                               6
# 2      RETIRO                              2                               6
# 3   SALAMANCA                              4                              44
# 4   CHAMARTÍN                              5                               7
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                      0                     198                    111
# 1                      1                      12                      0
# 2                      0                       6                      2
# 3                      1                      18                      1
# 4                      1                      36                     43
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                190
# 1  ARGANZUELA                                 21
# 2      RETIRO                                  7
# 3   SALAMANCA                                 55
# 4   CHAMARTÍN                                 20
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            47            62
# 1  ARGANZUELA            30            50
# 2      RETIRO            51            43
# 3   SALAMANCA            58            57
# 4   CHAMARTÍN            45            58
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO           45
# 1  ARGANZUELA           13
# 2      RETIRO            5
# 3   SALAMANCA           10
# 4   CHAMARTÍN           50
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                 140                         16
# 1  ARGANZUELA                                  11                          1
# 2      RETIRO                                  14                          0
# 3   SALAMANCA                                   3                          1
# 4   CHAMARTÍN                                  26                         13
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                      12                                5
# 1  ARGANZUELA                       0                                9
# 2      RETIRO                       7                               30
# 3   SALAMANCA                       2                                3
# 4   CHAMARTÍN                       0                               24

# %% [markdown]
# ## ENERO 2024

# %%
# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Enero 2024/DATOS EN FORMATO REUTILIZABLE ENERO 2024.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")

# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Enero 2024/{hoja.lower().replace(" ", "_")}.csv', index=False)
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             22                             126
# 1  ARGANZUELA                              1                               6
# 2      RETIRO                              4                               9
# 3   SALAMANCA                              1                              46
# 4   CHAMARTÍN                              3                               8
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                     44                     230                     58
# 1                      0                      15                      2
# 2                      2                       1                      2
# 3                      2                       8                      3
# 4                      2                      46                     20
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                200
# 1  ARGANZUELA                                 20
# 2      RETIRO                                  9
# 3   SALAMANCA                                 64
# 4   CHAMARTÍN                                 32
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            35            65
# 1  ARGANZUELA            42            50
# 2      RETIRO            30            39
# 3   SALAMANCA            55            62
# 4   CHAMARTÍN            42            71
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO           28
# 1  ARGANZUELA           15
# 2      RETIRO            8
# 3   SALAMANCA           13
# 4   CHAMARTÍN            8
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                 399                         29
# 1  ARGANZUELA                                   2                          0
# 2      RETIRO                                  25                          3
# 3   SALAMANCA                                  28                          0
# 4   CHAMARTÍN                                  10                         12
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                       9                                5
# 1  ARGANZUELA                       3                               13
# 2      RETIRO                       1                               19
# 3   SALAMANCA                       4                                5
# 4   CHAMARTÍN                       1                               13

# %% [markdown]
# ## DICIEMBRE 2023.

# %%
# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Diciembre 2023/DATOS EN FORMATO REUTILIZABLE DICIEMBRE 2023.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")

# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Diciembre 2023/{hoja.lower().replace(" ", "_")}.csv', index=False)
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             29                             145
# 1  ARGANZUELA                              4                               4
# 2      RETIRO                              1                               7
# 3   SALAMANCA                             10                              49
# 4   CHAMARTÍN                              7                               8
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                    645                     243                     35
# 1                      1                       7                      1
# 2                      0                       3                      1
# 3                      0                       5                      0
# 4                      1                     105                     27
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                294
# 1  ARGANZUELA                                 28
# 2      RETIRO                                 15
# 3   SALAMANCA                                 71
# 4   CHAMARTÍN                                 25
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            42            63
# 1  ARGANZUELA            36            43
# 2      RETIRO            48            46
# 3   SALAMANCA            60            67
# 4   CHAMARTÍN            56            82
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO           28
# 1  ARGANZUELA           21
# 2      RETIRO            5
# 3   SALAMANCA           13
# 4   CHAMARTÍN           20
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                1515                         13
# 1  ARGANZUELA                                   1                          1
# 2      RETIRO                                  33                          3
# 3   SALAMANCA                                   0                          0
# 4   CHAMARTÍN                                  30                          3
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                      30                                1
# 1  ARGANZUELA                       2                                4
# 2      RETIRO                       6                               16
# 3   SALAMANCA                       0                                2
# 4   CHAMARTÍN                       1                                1

# %% [markdown]
# ## NOVIEMBRE 2023.

# %%
# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Noviembre 2023/DATOS EN FORMATO REUTILIZABLE NOVIEMBRE 2023.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")

# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Noviembre 2023/{hoja.lower().replace(" ", "_")}.csv', index=False)
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             40                             110
# 1  ARGANZUELA                              1                              10
# 2      RETIRO                              1                               4
# 3   SALAMANCA                              9                              39
# 4   CHAMARTÍN                              4                              12
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                    115                     297                     54
# 1                      1                       8                      1
# 2                      0                      14                      1
# 3                      1                       7                      1
# 4                      4                      68                     38
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                192
# 1  ARGANZUELA                                 19
# 2      RETIRO                                  9
# 3   SALAMANCA                                 53
# 4   CHAMARTÍN                                 23
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            63            66
# 1  ARGANZUELA            41            47
# 2      RETIRO            38            56
# 3   SALAMANCA            59            69
# 4   CHAMARTÍN            51            85
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO           45
# 1  ARGANZUELA           12
# 2      RETIRO            8
# 3   SALAMANCA           17
# 4   CHAMARTÍN           21
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                 705                         30
# 1  ARGANZUELA                                   4                          2
# 2      RETIRO                                  17                          6
# 3   SALAMANCA                                   2                          0
# 4   CHAMARTÍN                                  17                         18
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                      22                                7
# 1  ARGANZUELA                       0                                3
# 2      RETIRO                       0                               13
# 3   SALAMANCA                       0                                7
# 4   CHAMARTÍN                       4                                9

# %% [markdown]
# ## OCTUBRE 2023.

# %%
# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Octubre 2023/DATOS EN FORMATO REUTILIZABLE OCTUBRE 2023.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")

# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Octubre 2023/{hoja.lower().replace(" ", "_")}.csv', index=False)
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             38                             108
# 1  ARGANZUELA                             10                               6
# 2      RETIRO                              4                               5
# 3   SALAMANCA                             10                              56
# 4   CHAMARTÍN                              1                               7
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                     13                     272                     85
# 1                      0                      17                      1
# 2                      1                       5                      0
# 3                      2                      15                      0
# 4                      1                      18                      2
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                184
# 1  ARGANZUELA                                 25
# 2      RETIRO                                 14
# 3   SALAMANCA                                 78
# 4   CHAMARTÍN                                 19
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            55            72
# 1  ARGANZUELA            44            45
# 2      RETIRO            48            48
# 3   SALAMANCA            69            62
# 4   CHAMARTÍN            65            75
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO           94
# 1  ARGANZUELA           16
# 2      RETIRO           21
# 3   SALAMANCA           26
# 4   CHAMARTÍN           21
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                 401                         17
# 1  ARGANZUELA                                   9                          5
# 2      RETIRO                                  20                          5
# 3   SALAMANCA                                   7                          3
# 4   CHAMARTÍN                                  34                         16
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                      16                                4
# 1  ARGANZUELA                       0                                1
# 2      RETIRO                       3                               24
# 3   SALAMANCA                       5                                5
# 4   CHAMARTÍN                       0                                1

# %% [markdown]
# ## SEPTIEMBRE 2023.

# %%
# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Septiembre 2023/DATOS EN FORMATO REUTILIZABLE SEPTIEMBRE 2023.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")

# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Septiembre 2023/{hoja.lower().replace(" ", "_")}.csv', index=False)
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             31                              92
# 1  ARGANZUELA                              2                               5
# 2      RETIRO                              2                               6
# 3   SALAMANCA                              4                              39
# 4   CHAMARTÍN                              6                              10
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                      5                     181                     50
# 1                      3                      34                      1
# 2                      0                      11                      1
# 3                      2                       5                      0
# 4                      1                      59                     52
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                182
# 1  ARGANZUELA                                 21
# 2      RETIRO                                 13
# 3   SALAMANCA                                 50
# 4   CHAMARTÍN                                 17
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            44            63
# 1  ARGANZUELA            27            39
# 2      RETIRO            35            57
# 3   SALAMANCA            57            70
# 4   CHAMARTÍN            62            71
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO           67
# 1  ARGANZUELA           18
# 2      RETIRO           10
# 3   SALAMANCA           20
# 4   CHAMARTÍN           12
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                 111                         16
# 1  ARGANZUELA                                   0                          5
# 2      RETIRO                                  20                          7
# 3   SALAMANCA                                   2                          2
# 4   CHAMARTÍN                                  13                          9
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                      16                               17
# 1  ARGANZUELA                       0                                2
# 2      RETIRO                       5                               10
# 3   SALAMANCA                       3                               16
# 4   CHAMARTÍN                       0                                6

# %% [markdown]
# ## AGOSTO 2023.

# %%
# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Agosto 2023/DATOS EN FORMATO REUTILIZABLE AGOSTO 2023.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")

# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Agosto 2023/{hoja.lower().replace(" ", "_")}.csv', index=False)
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             24                              97
# 1  ARGANZUELA                              3                               5
# 2      RETIRO                              2                               4
# 3   SALAMANCA                              3                              31
# 4   CHAMARTÍN                              7                               7
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                      0                      29                     13
# 1                      2                       8                      0
# 2                      0                       5                      2
# 3                      1                       4                      0
# 4                     12                      36                      5
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                152
# 1  ARGANZUELA                                 15
# 2      RETIRO                                 13
# 3   SALAMANCA                                 37
# 4   CHAMARTÍN                                 20
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            38            43
# 1  ARGANZUELA            23            27
# 2      RETIRO            35            16
# 3   SALAMANCA            35            35
# 4   CHAMARTÍN            32            29
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO           77
# 1  ARGANZUELA           27
# 2      RETIRO            6
# 3   SALAMANCA            5
# 4   CHAMARTÍN           15
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                 104                        172
# 1  ARGANZUELA                                   2                          4
# 2      RETIRO                                  29                         11
# 3   SALAMANCA                                   7                          0
# 4   CHAMARTÍN                                  10                          4
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                      18                                0
# 1  ARGANZUELA                       0                                0
# 2      RETIRO                       2                                0
# 3   SALAMANCA                       0                                0
# 4   CHAMARTÍN                       0                                0

# %% [markdown]
# ## Julio 2024.

# %%
# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Julio 2023/DATOS EN FORMATO REUTILIZABLE JULIO 2023.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")

# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Julio 2023/{hoja.lower().replace(" ", "_")}.csv', index=False)
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             17                              75
# 1  ARGANZUELA                              3                               4
# 2      RETIRO                              5                               5
# 3   SALAMANCA                              9                              31
# 4   CHAMARTÍN                              1                               7
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                     18                     178                     25
# 1                      2                       9                      2
# 2                      0                       5                      2
# 3                      0                      25                      1
# 4                      1                      29                      2
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                155
# 1  ARGANZUELA                                 16
# 2      RETIRO                                  7
# 3   SALAMANCA                                 34
# 4   CHAMARTÍN                                  9
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            72            68
# 1  ARGANZUELA            31            38
# 2      RETIRO            48            33
# 3   SALAMANCA            60            65
# 4   CHAMARTÍN            44            68
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO           57
# 1  ARGANZUELA           23
# 2      RETIRO            9
# 3   SALAMANCA            8
# 4   CHAMARTÍN           12
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                 109                         92
# 1  ARGANZUELA                                   4                          3
# 2      RETIRO                                  32                         27
# 3   SALAMANCA                                   2                         13
# 4   CHAMARTÍN                                   3                          0
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                      21                                1
# 1  ARGANZUELA                       1                                1
# 2      RETIRO                       1                                0
# 3   SALAMANCA                       0                                0
# 4   CHAMARTÍN                       0                                0

# %% [markdown]
# ## Junio 2023.

# %%
# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Junio 2023/DATOS EN FORMATO REUTILIZABLE JUNIO 2023.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")

# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Junio 2023/{hoja.lower().replace(" ", "_")}.csv', index=False)
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             31                             135
# 1  ARGANZUELA                              2                               7
# 2      RETIRO                              3                               9
# 3   SALAMANCA                              9                              37
# 4   CHAMARTÍN                              5                               4
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                     12                     153                     41
# 1                      3                       2                      1
# 2                      2                      13                      7
# 3                      0                      12                      3
# 4                      0                      35                      5
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                173
# 1  ARGANZUELA                                 15
# 2      RETIRO                                 13
# 3   SALAMANCA                                 48
# 4   CHAMARTÍN                                 31
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            40            60
# 1  ARGANZUELA            31            42
# 2      RETIRO            42            47
# 3   SALAMANCA            65            48
# 4   CHAMARTÍN            52            60
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO           52
# 1  ARGANZUELA           42
# 2      RETIRO           14
# 3   SALAMANCA           13
# 4   CHAMARTÍN           18
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                 117                        104
# 1  ARGANZUELA                                   0                          5
# 2      RETIRO                                   6                          8
# 3   SALAMANCA                                   0                          6
# 4   CHAMARTÍN                                   1                          6
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                      12                                5
# 1  ARGANZUELA                       1                               12
# 2      RETIRO                       1                               12
# 3   SALAMANCA                       0                                4
# 4   CHAMARTÍN                       1                                0

# %% [markdown]
# ## MAYO 2023.

# %%
# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Mayo 2023/DATOS EN FORMATO REUTILIZABLE MAYO 2023.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")

# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Mayo 2023/{hoja.lower().replace(" ", "_")}.csv', index=False)
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             47                             125
# 1  ARGANZUELA                              2                               6
# 2      RETIRO                              3                               7
# 3   SALAMANCA                              7                              25
# 4   CHAMARTÍN                              6                              14
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                      7                     204                     44
# 1                      0                       9                      5
# 2                      1                      25                      4
# 3                      1                      21                      1
# 4                      1                      53                     26
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                188
# 1  ARGANZUELA                                 16
# 2      RETIRO                                 16
# 3   SALAMANCA                                 45
# 4   CHAMARTÍN                                 23
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            47            65
# 1  ARGANZUELA            45            47
# 2      RETIRO            33            40
# 3   SALAMANCA            65            70
# 4   CHAMARTÍN            58            53
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO           44
# 1  ARGANZUELA           19
# 2      RETIRO           11
# 3   SALAMANCA           19
# 4   CHAMARTÍN           23
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                 192                        153
# 1  ARGANZUELA                                   2                          5
# 2      RETIRO                                  39                         30
# 3   SALAMANCA                                   3                          4
# 4   CHAMARTÍN                                   8                         21
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                      20                               11
# 1  ARGANZUELA                       2                               16
# 2      RETIRO                      11                                8
# 3   SALAMANCA                       0                                0
# 4   CHAMARTÍN                       0                                4

# %% [markdown]
# ## Abril 2023.

# %%
# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Abril 2023/DATOS EN FORMATO REUTILIZABLE ABRIL 2023.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")

# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Abril 2023/{hoja.lower().replace(" ", "_")}.csv', index=False)
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             40                             122
# 1  ARGANZUELA                              4                               5
# 2      RETIRO                              2                               8
# 3   SALAMANCA                              2                              36
# 4   CHAMARTÍN                              4                              12
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                     10                     220                     36
# 1                      0                       8                      2
# 2                      0                      13                      0
# 3                      4                      23                      0
# 4                      1                      68                     23
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                176
# 1  ARGANZUELA                                 20
# 2      RETIRO                                 17
# 3   SALAMANCA                                 58
# 4   CHAMARTÍN                                 20
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            61            63
# 1  ARGANZUELA            41            33
# 2      RETIRO            38            34
# 3   SALAMANCA            45            73
# 4   CHAMARTÍN            50            46
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO           54
# 1  ARGANZUELA            8
# 2      RETIRO            3
# 3   SALAMANCA           11
# 4   CHAMARTÍN           16
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                  55                         48
# 1  ARGANZUELA                                   2                          2
# 2      RETIRO                                  42                         19
# 3   SALAMANCA                                   4                          2
# 4   CHAMARTÍN                                  19                         26
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                       9                               10
# 1  ARGANZUELA                       0                               15
# 2      RETIRO                       4                               12
# 3   SALAMANCA                       0                                5
# 4   CHAMARTÍN                       0                                4

# %% [markdown]
# ## Marzo 2023.

# %%
# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Marzo 2023/DATOS EN FORMATO REUTILIZABLE MARZO 2023.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")

# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Marzo 2023/{hoja.lower().replace(" ", "_")}.csv', index=False)
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             33                             100
# 1  ARGANZUELA                              8                               7
# 2      RETIRO                              5                               3
# 3   SALAMANCA                              5                              41
# 4   CHAMARTÍN                              3                               6
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                      5                     328                     48
# 1                      0                      15                      2
# 2                      1                       7                      5
# 3                      2                      13                      2
# 4                      5                      65                     18
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                178
# 1  ARGANZUELA                                 29
# 2      RETIRO                                 13
# 3   SALAMANCA                                 64
# 4   CHAMARTÍN                                 29
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            54            74
# 1  ARGANZUELA            29            48
# 2      RETIRO            37            50
# 3   SALAMANCA            56            73
# 4   CHAMARTÍN            70            64
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO           42
# 1  ARGANZUELA           14
# 2      RETIRO            9
# 3   SALAMANCA           10
# 4   CHAMARTÍN            9
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                 159                         84
# 1  ARGANZUELA                                   0                          2
# 2      RETIRO                                  12                          6
# 3   SALAMANCA                                   1                          0
# 4   CHAMARTÍN                                  22                          5
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                      13                               10
# 1  ARGANZUELA                       0                               17
# 2      RETIRO                       0                                3
# 3   SALAMANCA                       0                                9
# 4   CHAMARTÍN                       1                                6

# %% [markdown]
# ## Febrero 2023.

# %%
# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Febrero 2023/DATOS EN FORMATO REUTILIZABLE FEBRERO 2023.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")

# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Febrero 2023/{hoja.lower().replace(" ", "_")}.csv', index=False)
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             28                              93
# 1  ARGANZUELA                              0                               2
# 2      RETIRO                              4                               2
# 3   SALAMANCA                              3                              36
# 4   CHAMARTÍN                              3                               4
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                     10                     273                     48
# 1                      0                      13                      2
# 2                      1                       7                      1
# 3                      0                      11                      0
# 4                      0                      58                     26
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                116
# 1  ARGANZUELA                                 21
# 2      RETIRO                                  7
# 3   SALAMANCA                                 55
# 4   CHAMARTÍN                                 20
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            37            59
# 1  ARGANZUELA            40            50
# 2      RETIRO            32            54
# 3   SALAMANCA            51            38
# 4   CHAMARTÍN            41            59
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO          8.0
# 1  ARGANZUELA          0.0
# 2      RETIRO          0.0
# 3   SALAMANCA          0.0
# 4   CHAMARTÍN          3.0
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                 140                         57
# 1  ARGANZUELA                                   4                          3
# 2      RETIRO                                   9                          1
# 3   SALAMANCA                                   0                          0
# 4   CHAMARTÍN                                  29                          5
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                      27                                9
# 1  ARGANZUELA                       0                                6
# 2      RETIRO                       0                                5
# 3   SALAMANCA                       0                                0
# 4   CHAMARTÍN                       1                                7

# %% [markdown]
# ## ENERO 2023.

# %%
# Leer los archivos
file_path = ('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Enero 2023/DATOS EN FORMATO REUTILIZABLE ENERO 2023.xlsx')
hojas_interes = ['SEGURIDAD', 'PERS. DETENIDAS X DISTRITOS', 'ACCIDENTES', 'EXPEDIENTES OAC', 'VENTA AMBULANTE', 'AA.TT.']

# Crear un diccionario para almacenar los DataFrames con el nombre de cada hoja
dfs = {}

# Leer cada hoja de interés y almacenarla en el diccionario
for hoja in hojas_interes:
    df = pd.read_excel(file_path, sheet_name=hoja, header=2)  # Usar header=2 para que tome los títulos correctos
    dfs[hoja] = df

# Mostrar las primeras filas de cada DataFrame para verificar
for hoja, df in dfs.items():
    print(f"Primeras filas de la hoja '{hoja}':")
    print(df.head(), "\n")

# Guardar cada DataFrame en un archivo CSV (opcional)
for hoja, df in dfs.items():
    df.to_csv(f'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/Enero 2023/{hoja.lower().replace(" ", "_")}.csv', index=False)
# Out:
# Primeras filas de la hoja 'SEGURIDAD':
#     DISTRITOS  RELACIONADAS CON LAS PERSONAS  RELACIONADAS CON EL PATRIMONIO  \
# 0      CENTRO                             23                              89
# 1  ARGANZUELA                              2                               6
# 2      RETIRO                              1                               6
# 3   SALAMANCA                              9                              36
# 4   CHAMARTÍN                              7                              15
#
#    POR TENENCIA DE ARMAS  POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS
# 0                     21                     296                     60
# 1                      0                       5                      1
# 2                      0                       4                      1
# 3                      1                      26                      1
# 4                      1                      29                      5
#
# Primeras filas de la hoja 'PERS. DETENIDAS X DISTRITOS':
#     DISTRITOS  PERSONAS DETENIDAS E INVESTIGADAS
# 0      CENTRO                                147
# 1  ARGANZUELA                                 12
# 2      RETIRO                                 11
# 3   SALAMANCA                                 47
# 4   CHAMARTÍN                                 35
#
# Primeras filas de la hoja 'ACCIDENTES':
#     DISTRITOS  CON VICTIMAS  SIN VICTIMAS
# 0      CENTRO            44            61
# 1  ARGANZUELA            38            48
# 2      RETIRO            46            39
# 3   SALAMANCA            55            71
# 4   CHAMARTÍN            53            68
#
# Primeras filas de la hoja 'EXPEDIENTES OAC':
#    COMISARÍAS  EXPEDIENTES
# 0      CENTRO           55
# 1  ARGANZUELA           23
# 2      RETIRO            9
# 3   SALAMANCA            7
# 4   CHAMARTÍN            9
#
# Primeras filas de la hoja 'VENTA AMBULANTE':
#     DISTRITOS  PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0      CENTRO                                 194                         18
# 1  ARGANZUELA                                   3                          1
# 2      RETIRO                                  22                          3
# 3   SALAMANCA                                   2                          0
# 4   CHAMARTÍN                                  28                          4
#
# Primeras filas de la hoja 'AA.TT.':
#     DISTRITOS  EXPEDIENTES INSTRUIDOS  CONTACTOS CON CENTROS ESCOLARES
# 0      CENTRO                       8                                4
# 1  ARGANZUELA                       0                                8
# 2      RETIRO                       1                                0
# 3   SALAMANCA                       0                                0
# 4   CHAMARTÍN                       3                                1

# %% [markdown]
# ## UNION DE TODOS LOS DATASETS

# %%
import os

# Definir la ruta base de los archivos CSV
# Definir la ruta base de los archivos CSV
ruta_base = 'C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/Madrid/'

# Lista de nombres de archivos CSV
archivos_csv = [
    'aa.tt..csv',
    'accidentes.csv',
    'expedientes_oac.csv',
    'pers._detenidas_x_distritos.csv',
    'seguridad.csv',
    'venta_ambulante.csv'
]

# Obtener la lista de carpetas (meses)
carpetas_meses = [os.path.join(ruta_base, carpeta) for carpeta in os.listdir(ruta_base) if os.path.isdir(os.path.join(ruta_base, carpeta))]

# Diccionario para almacenar DataFrames de cada mes
dfs_meses = {}

# Recorrer cada carpeta de mes y leer los archivos CSV
for carpeta in carpetas_meses:
    dfs = {}
    for archivo in archivos_csv:
        ruta_archivo = os.path.join(carpeta, archivo)
        if os.path.exists(ruta_archivo):
            df = pd.read_csv(ruta_archivo)
            if 'COMISARÍAS' in df.columns:
                df.rename(columns={'COMISARÍAS': 'DISTRITOS'}, inplace=True)
            dfs[archivo] = df
        else:
            print(f"El archivo {ruta_archivo} no existe.")
    
    # Verificar que todos los DataFrames tienen la columna 'DISTRITOS'
    for archivo, df in dfs.items():
        if 'DISTRITOS' not in df.columns:
            print(f"El archivo {archivo} no contiene la columna 'DISTRITOS'. Las columnas son: {df.columns}")

    # Inicializar el DataFrame final con el primer DataFrame de la lista
    df_ind_criminalidad = dfs[archivos_csv[0]]
    
    # Realizar un outer join con los demás DataFrames basado en la columna 'DISTRITOS'
    for archivo in archivos_csv[1:]:
        if archivo in dfs and 'DISTRITOS' in dfs[archivo].columns:
            df_ind_criminalidad = pd.merge(df_ind_criminalidad, dfs[archivo], on='DISTRITOS', how='outer')
        else:
            print(f"Omitiendo el archivo {archivo} porque no tiene la columna 'DISTRITOS'.")
    
    # Guardar el DataFrame resultante de cada mes en el diccionario
    mes = os.path.basename(carpeta)
    dfs_meses[mes] = df_ind_criminalidad

# Unir los DataFrames de todos los meses
df_final = pd.concat(dfs_meses.values(), ignore_index=True)

# %%
dfs_meses
# Out:
# {'Abril 2023':                 DISTRITOS  EXPEDIENTES INSTRUIDOS  \
#  0              ARGANZUELA                     0.0
#  1                 BARAJAS                     1.0
#  2             CARABANCHEL                     0.0
#  3                  CENTRO                     9.0
#  4               CHAMARTÍN                     0.0
#  5                CHAMBERÍ                     5.0
#  6           CIUDAD LINEAL                     1.0
#  7   FUENCARRAL - EL PARDO                     4.0
#  8               HORTALEZA                     7.0
#  9                  LATINA                     0.0
#  10      MONCLOA - ARAVACA                     1.0
#  11              MORATALAZ                     7.0
#  12       OTRAS COMISARÍAS                     NaN
#  13     PUENTE DE VALLECAS                     6.0
#  14                 RETIRO                     4.0
#  15              SALAMANCA                     0.0
#  16  SAN BLAS - CANILLEJAS                     7.0
#  17  SIN DISTRITO ASIGNADO                     0.0
#  18                 TETUÁN                     3.0
#  19                  TOTAL                    72.0
#  20                  USERA                     2.0
#  21              VICÁLVARO                    11.0
#  22      VILLA DE VALLECAS                     0.0
#  23             VILLAVERDE                     4.0
#
#      CONTACTOS CON CENTROS ESCOLARES  CON VICTIMAS  SIN VICTIMAS  EXPEDIENTES  \
#  0                              15.0          41.0          33.0          8.0
#  1                              27.0           5.0          15.0          5.0
#  2                              18.0          43.0          62.0         26.0
#  3                              10.0          61.0          63.0         54.0
#  4                               4.0          50.0          46.0         16.0
#  5                               9.0          32.0          38.0         20.0
#  6                               1.0          49.0          57.0         23.0
#  7                              43.0          47.0          59.0         14.0
#  8                              55.0          21.0          29.0         12.0
#  9                               1.0          49.0          52.0         34.0
#  10                             21.0          49.0          46.0         18.0
#  11                             55.0          26.0          20.0          5.0
#  12                              NaN           NaN           NaN          9.0
#  13                             23.0          58.0          66.0         42.0
#  14                             12.0          38.0          34.0          3.0
#  15                              5.0          45.0          73.0         11.0
#  16                             31.0          37.0          51.0         12.0
#  17                              0.0           0.0           0.0          NaN
#  18                             37.0          30.0          33.0         17.0
#  19                            409.0         778.0         919.0        378.0
#  20                             20.0          32.0          43.0         16.0
#  21                              5.0          10.0          15.0          4.0
#  22                              0.0          26.0          48.0         15.0
#  23                             17.0          29.0          36.0         14.0
#
#      PERSONAS DETENIDAS E INVESTIGADAS  RELACIONADAS CON LAS PERSONAS  \
#  0                                20.0                            4.0
#  1                                 9.0                            4.0
#  2                                41.0                           19.0
#  3                               176.0                           40.0
#  4                                20.0                            4.0
#  5                                24.0                            5.0
#  6                                41.0                           16.0
#  7                                17.0                            7.0
#  8                                18.0                            1.0
#  9                                73.0                           16.0
#  10                               24.0                            5.0
#  11                                6.0                            7.0
#  12                                NaN                            NaN
#  13                               89.0                           25.0
#  14                               17.0                            2.0
#  15                               58.0                            2.0
#  16                               29.0                            3.0
#  17                                0.0                            0.0
#  18                               24.0                            6.0
#  19                              757.0                          189.0
#  20                               31.0                            6.0
#  21                                6.0                            6.0
#  22                               13.0                            3.0
#  23                               21.0                            8.0
#
#      RELACIONADAS CON EL PATRIMONIO  POR TENENCIA DE ARMAS  \
#  0                              5.0                    0.0
#  1                              3.0                    1.0
#  2                             21.0                    3.0
#  3                            122.0                   10.0
#  4                             12.0                    1.0
#  5                              5.0                    1.0
#  6                             17.0                    0.0
#  7                              7.0                    2.0
#  8                              6.0                    0.0
#  9                             14.0                    3.0
#  10                             7.0                    0.0
#  11                             3.0                    1.0
#  12                             NaN                    NaN
#  13                            47.0                   10.0
#  14                             8.0                    0.0
#  15                            36.0                    4.0
#  16                             9.0                    5.0
#  17                             0.0                    0.0
#  18                             9.0                    0.0
#  19                           373.0                   51.0
#  20                            11.0                    5.0
#  21                            10.0                    3.0
#  22                            13.0                    1.0
#  23                             8.0                    1.0
#
#      POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS  \
#  0                      8.0                    2.0
#  1                      7.0                    1.0
#  2                     32.0                    7.0
#  3                    220.0                   36.0
#  4                     68.0                   23.0
#  5                     85.0                    3.0
#  6                     24.0                    0.0
#  7                     21.0                    1.0
#  8                     50.0                    4.0
#  9                     29.0                    9.0
#  10                     5.0                    0.0
#  11                     3.0                    0.0
#  12                     NaN                    NaN
#  13                    49.0                    2.0
#  14                    13.0                    0.0
#  15                    23.0                    0.0
#  16                    12.0                    2.0
#  17                     0.0                    0.0
#  18                    15.0                    2.0
#  19                   704.0                  103.0
#  20                    16.0                    3.0
#  21                     2.0                    0.0
#  22                     6.0                    3.0
#  23                    16.0                    5.0
#
#      PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
#  0                                  2.0                        2.0
#  1                                  0.0                        1.0
#  2                                  4.0                       24.0
#  3                                 55.0                       48.0
#  4                                 19.0                       26.0
#  5                                  0.0                        1.0
#  6                                  2.0                        3.0
#  7                                  4.0                        3.0
#  8                                  3.0                        0.0
#  9                                  4.0                       84.0
#  10                                 0.0                       11.0
#  11                                 0.0                        0.0
#  12                                 NaN                        NaN
#  13                                19.0                       15.0
#  14                                42.0                       19.0
#  15                                 4.0                        2.0
#  16                                 0.0                       13.0
#  17                                 0.0                        0.0
#  18                                 6.0                        7.0
#  19                               187.0                      332.0
#  20                                 2.0                       40.0
#  21                                 0.0                        0.0
#  22                                 1.0                        4.0
#  23                                20.0                       29.0  ,
#  'Abril 2024':                 DISTRITOS  EXPEDIENTES INSTRUIDOS  \
#  0              ARGANZUELA                     0.0
#  1                 BARAJAS                     0.0
#  2             CARABANCHEL                    13.0
#  3                  CENTRO                    13.0
#  4               CHAMARTÍN                    13.0
#  5                CHAMBERÍ                     2.0
#  6           CIUDAD LINEAL                     2.0
#  7   FUENCARRAL - EL PARDO                     2.0
#  8               HORTALEZA                    12.0
#  9                  LATINA                     7.0
#  10      MONCLOA - ARAVACA                     3.0
#  11              MORATALAZ                     7.0
#  12       OTRAS COMISARÍAS                     NaN
#  13     PUENTE DE VALLECAS                    21.0
#  14                 RETIRO                     4.0
#  15              SALAMANCA                     5.0
#  16  SAN BLAS - CANILLEJAS                     9.0
#  17  SIN DISTRITO ASIGNADO                     0.0
#  4                              8.0                    1.0
#  5                              8.0                    2.0
#  6                              9.0                    2.0
#  7                              4.0                    4.0
#  8                              1.0                    2.0
#  9                             10.0                    0.0
#  10                             9.0                    0.0
#  11                             4.0                    0.0
#  12                             NaN                    NaN
#  13                            27.0                    2.0
#  14                             7.0                    0.0
#  15                            49.0                    0.0
#  16                             7.0                    2.0
#  17                             0.0                    0.0
#  18                             4.0                    0.0
#  19                           360.0                  678.0
#  20                             4.0                    0.0
#  21                             1.0                    6.0
#  22                            24.0                    4.0
#  23                             6.0                    4.0
#
#      POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS  \
#  0                      7.0                    1.0
#  1                      4.0                    0.0
#  2                     22.0                    1.0
#  3                    243.0                   35.0
#  4                    105.0                   27.0
#  5                     35.0                    1.0
#  6                      7.0                    0.0
#  7                     13.0                    0.0
#  8                     18.0                    1.0
#  9                     11.0                    1.0
#  10                     7.0                    1.0
#  11                     2.0                    1.0
#  12                     NaN                    NaN
#  13                    27.0                    4.0
#  14                     3.0                    1.0
#  15                     5.0                    0.0
#  16                    19.0                    0.0
#  17                     0.0                    0.0
#  18                    10.0                    0.0
#  19                   583.0                   84.0
#  20                     2.0                    0.0
#  21                    20.0                    4.0
#  22                     7.0                    2.0
#  23                    16.0                    4.0
#
#      PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
#  0                                  1.0                        1.0
#  1                                  2.0                        1.0
#  2                                 13.0                        4.0
#  3                               1515.0                       13.0
#  4                                 30.0                        3.0
#  5                                  4.0                        3.0
#  6                                  1.0                        3.0
#  7                                  1.0                        0.0
#  8                                  0.0                        4.0
#  9                                 11.0                       12.0
#  10                                 1.0                        0.0
#  11                                 0.0                        0.0
#  12                                 NaN                        NaN
#  13                                11.0                        1.0
#  14                                33.0                        3.0
#  15                                 0.0                        0.0
#  16                                 0.0                        1.0
#  17                                 0.0                        0.0
#  18                                13.0                        2.0
#  19                              1655.0                       88.0
#  20                                 8.0                       15.0
#  21                                 1.0                        1.0
#  22                                 1.0                        0.0
#  23                                 9.0                       21.0  ,
#  'Enero 2023':                 DISTRITOS  EXPEDIENTES INSTRUIDOS  \
#  0              ARGANZUELA                     0.0
#  1                 BARAJAS                     0.0
#  2             CARABANCHEL                     1.0
#  3                  CENTRO                     8.0
#  4               CHAMARTÍN                     3.0
#  5                CHAMBERÍ                     3.0
#  6           CIUDAD LINEAL                     3.0
#  7   FUENCARRAL - EL PARDO                     5.0
#  8               HORTALEZA                     2.0
#  9                  LATINA                     1.0
#  10      MONCLOA - ARAVACA                     0.0
#  11              MORATALAZ                     1.0
#  12         OTRAS UNIDADES                     NaN
#  13     PUENTE DE VALLECAS                     2.0
#  14                 RETIRO                     1.0
#  15              SALAMANCA                     0.0
#  16  SAN BLAS - CANILLEJAS                     6.0
#  17  SIN DISTRITO ASIGNADO                     0.0
#  18                 TETUÁN                     2.0
#  19                  TOTAL                    50.0
#  20                  USERA                     0.0
#  21              VICÁLVARO                    11.0
#  22      VILLA DE VALLECAS                     0.0
#  23             VILLAVERDE                     1.0
#
#      CONTACTOS CON CENTROS ESCOLARES  CON VICTIMAS  SIN VICTIMAS  EXPEDIENTES  \
#  1                 BARAJAS                     0.0
#  2             CARABANCHEL                     3.0
#  3                  CENTRO                    16.0
#  4               CHAMARTÍN                     0.0
#  5                CHAMBERÍ                     0.0
#  6           CIUDAD LINEAL                     1.0
#  7   FUENCARRAL - EL PARDO                     3.0
#  8               HORTALEZA                     6.0
#  9                  LATINA                     0.0
#  10      MONCLOA - ARAVACA                     0.0
#  11              MORATALAZ                     1.0
#  12       OTRAS COMISARÍAS                     NaN
#  13     PUENTE DE VALLECAS                     3.0
#  14                 RETIRO                     5.0
#  15              SALAMANCA                     3.0
#  16  SAN BLAS - CANILLEJAS                     3.0
#  17  SIN DISTRITO ASIGNADO                     0.0
#  18                 TETUÁN                     5.0
#  19                  TOTAL                    57.0
#  20                  USERA                     3.0
#  21              VICÁLVARO                     2.0
#  22      VILLA DE VALLECAS                     1.0
#  23             VILLAVERDE                     2.0
#
#      CONTACTOS CON CENTROS ESCOLARES  CON VICTIMAS  SIN VICTIMAS  EXPEDIENTES  \
#  0                               2.0          27.0          39.0         18.0
#  1                              26.0          10.0          24.0          4.0
#  2                               9.0          49.0          52.0         57.0
#  3                              17.0          44.0          63.0         67.0
#  4                               6.0          62.0          71.0         12.0
#  5                               2.0          38.0          41.0         20.0
#  6                              11.0          47.0          60.0         27.0
#  7                              51.0          37.0          52.0         34.0
#  8                              60.0          30.0          36.0         14.0
#  9                              20.0          35.0          62.0         31.0
#  10                             13.0          38.0          45.0          8.0
#  11                             33.0          14.0          24.0          6.0
#  12                              NaN           NaN           NaN         16.0
#  13                             23.0          48.0          94.0         55.0
#  14                             10.0          35.0          57.0         10.0
#  15                             16.0          57.0          70.0         20.0
#  16                             33.0          32.0          43.0         23.0
#  17                              0.0           0.0           0.0          NaN
#  18                             17.0          44.0          36.0         23.0
#  19                            410.0         736.0         994.0        511.0
#  20                              7.0          27.0          34.0         27.0
#  21                              6.0          17.0          20.0          7.0
#  22                              0.0          18.0          33.0         18.0
#  23                             48.0          27.0          38.0         14.0
#
#      PERSONAS DETENIDAS E INVESTIGADAS  RELACIONADAS CON LAS PERSONAS  \
#  0                                21.0                            2.0
#  1                                10.0                            2.0
#  2                                41.0                            9.0
#  3                               182.0                           31.0
#  4                                17.0                            6.0
#  5                                12.0                            3.0
#  6                                45.0                           12.0
#  7                                12.0                            0.0
#  8                                22.0                            5.0
#  9                                42.0                            8.0
#  10                               12.0                           12.0
#  11                                8.0                            3.0
#  12                                NaN                            NaN
#  13                               72.0                           16.0
#  14                               13.0                            2.0
#  15                               50.0                            4.0
#  16                               18.0                            6.0
#  17                                0.0                            0.0
#  18                               30.0                            9.0
#  19                              655.0                          143.0
#  20                               12.0                            2.0
#  21                                4.0                            1.0
#  22                               12.0                            3.0
#  23                               20.0                            7.0
#
#      RELACIONADAS CON EL PATRIMONIO  POR TENENCIA DE ARMAS  \
#  0                              5.0                    3.0
#  1                              2.0                    1.0
#  2                             25.0                    5.0
#  3                             92.0                    5.0
#  4                             10.0                    1.0
#  5                              6.0                    2.0
#  6                             12.0                    5.0
#  7                              4.0                    0.0
#  8                              5.0                    1.0
#  9                             10.0                   11.0
#  10                            13.0                    1.0
#  11                             5.0                    4.0
#  12                             NaN                    NaN
#  13                            47.0                   14.0
#  14                             6.0                    0.0
#  15                            39.0                    2.0
#  16                            10.0                    1.0
#  17                             0.0                    0.0
#  18                             8.0                    3.0
#  19                           320.0                   67.0
#  20                             1.0                    5.0
#  21                             6.0                    1.0
#  22                             5.0                    1.0
#  23                             9.0                    1.0
#
#      POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS  \
#  0                     34.0                    1.0
#  1                     14.0                   14.0
#  2                     28.0                    3.0
#  3                    181.0                   50.0
#  4                     59.0                   52.0
#  5                     32.0                    5.0
#  6                     68.0                    1.0
#  7                      7.0                    0.0
#  8                     16.0                    2.0
#  9                     29.0                    3.0
#  10                    30.0                    5.0
#  11                     3.0                    2.0
#  12                     NaN                    NaN
#  13                    67.0                    4.0
#  14                    11.0                    1.0
#  15                     5.0                    0.0
#  16                    14.0                    1.0
#  17                     0.0                    0.0
#  18                     9.0                    2.0
#  19                   668.0                  163.0
#  20                     9.0                    5.0
#  21                     7.0                    3.0
#  22                    18.0                    4.0
#  23                    27.0                    5.0
#
#      PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
#  0                                  0.0                        5.0
#  1                                  0.0                        2.0
#  2                                  9.0                       54.0
#  3                                111.0                       16.0
#  4                                 13.0                        9.0
#  5                                  1.0                        6.0
#  6                                  0.0                        6.0
#  7                                  0.0                        1.0
#  8                                  1.0                        3.0
#  9                                  6.0                       25.0
#  10                                 1.0                        3.0
#  11                                 0.0                        0.0
#  12                                 NaN                        NaN
#  13                                 5.0                       16.0
#  14                                20.0                        7.0
#  15                                 2.0                        2.0
#  16                                 2.0                       13.0
#  17                                 0.0                        0.0
#  18                                 5.0                        5.0
#  19                               217.0                      227.0
#  20                                13.0                       36.0
#  21                                 0.0                        0.0
#  22                                 1.0                        2.0
#  23                                27.0                       16.0  }

# %%
# Verificar el DataFrame resultante
print(df_final)
# Out:
#              DISTRITOS  EXPEDIENTES INSTRUIDOS  \
# 0           ARGANZUELA                     0.0
# 1              BARAJAS                     1.0
# 2          CARABANCHEL                     0.0
# 3               CENTRO                     9.0
# 4            CHAMARTÍN                     0.0
# ..                 ...                     ...
# 381              TOTAL                    57.0
# 382              USERA                     3.0
# 383          VICÁLVARO                     2.0
# 384  VILLA DE VALLECAS                     1.0
# 385         VILLAVERDE                     2.0
#
#      CONTACTOS CON CENTROS ESCOLARES  CON VICTIMAS  SIN VICTIMAS  EXPEDIENTES  \
# 0                               15.0          41.0          33.0          8.0
# 1                               27.0           5.0          15.0          5.0
# 2                               18.0          43.0          62.0         26.0
# 3                               10.0          61.0          63.0         54.0
# 4                                4.0          50.0          46.0         16.0
# ..                               ...           ...           ...          ...
# 381                            410.0         736.0         994.0        511.0
# 382                              7.0          27.0          34.0         27.0
# 383                              6.0          17.0          20.0          7.0
# 384                              0.0          18.0          33.0         18.0
# 385                             48.0          27.0          38.0         14.0
#
#      PERSONAS DETENIDAS E INVESTIGADAS  RELACIONADAS CON LAS PERSONAS  \
# 0                                 20.0                            4.0
# 1                                  9.0                            4.0
# 2                                 41.0                           19.0
# 3                                176.0                           40.0
# 4                                 20.0                            4.0
# ..                                 ...                            ...
# 381                              655.0                          143.0
# 382                               12.0                            2.0
# 383                                4.0                            1.0
# 384                               12.0                            3.0
# 385                               20.0                            7.0
#
#      RELACIONADAS CON EL PATRIMONIO  POR TENENCIA DE ARMAS  \
# 0                               5.0                    0.0
# 1                               3.0                    1.0
# 2                              21.0                    3.0
# 3                             122.0                   10.0
# 4                              12.0                    1.0
# ..                              ...                    ...
# 381                           320.0                   67.0
# 382                             1.0                    5.0
# 383                             6.0                    1.0
# 384                             5.0                    1.0
# 385                             9.0                    1.0
#
#      POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS  \
# 0                       8.0                    2.0
# 1                       7.0                    1.0
# 2                      32.0                    7.0
# 3                     220.0                   36.0
# 4                      68.0                   23.0
# ..                      ...                    ...
# 381                   668.0                  163.0
# 382                     9.0                    5.0
# 383                     7.0                    3.0
# 384                    18.0                    4.0
# 385                    27.0                    5.0
#
#      PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 0                                   2.0                        2.0
# 1                                   0.0                        1.0
# 2                                   4.0                       24.0
# 3                                  55.0                       48.0
# 4                                  19.0                       26.0
# ..                                  ...                        ...
# 381                               217.0                      227.0
# 382                                13.0                       36.0
# 383                                 0.0                        0.0
# 384                                 1.0                        2.0
# 385                                27.0                       16.0
#
# [386 rows x 14 columns]

# %%
# Guardar el DataFrame resultante en un archivo CSV
df_final.to_csv(ruta_base + 'df_ind_criminalidad.csv', index=False)

# %%
# Eliminar las columnas que contienen solo valores NaN
df_ind_criminalidad_Madrid = df_final.dropna(axis=1, how='all')

# Verificar el DataFrame resultante
print(df_ind_criminalidad_Madrid.tail())
# Out:
#              DISTRITOS  EXPEDIENTES INSTRUIDOS  \
# 381              TOTAL                    57.0
# 382              USERA                     3.0
# 383          VICÁLVARO                     2.0
# 384  VILLA DE VALLECAS                     1.0
# 385         VILLAVERDE                     2.0
#
#      CONTACTOS CON CENTROS ESCOLARES  CON VICTIMAS  SIN VICTIMAS  EXPEDIENTES  \
# 381                            410.0         736.0         994.0        511.0
# 382                              7.0          27.0          34.0         27.0
# 383                              6.0          17.0          20.0          7.0
# 384                              0.0          18.0          33.0         18.0
# 385                             48.0          27.0          38.0         14.0
#
#      PERSONAS DETENIDAS E INVESTIGADAS  RELACIONADAS CON LAS PERSONAS  \
# 381                              655.0                          143.0
# 382                               12.0                            2.0
# 383                                4.0                            1.0
# 384                               12.0                            3.0
# 385                               20.0                            7.0
#
#      RELACIONADAS CON EL PATRIMONIO  POR TENENCIA DE ARMAS  \
# 381                           320.0                   67.0
# 382                             1.0                    5.0
# 383                             6.0                    1.0
# 384                             5.0                    1.0
# 385                             9.0                    1.0
#
#      POR TENENCIA DE DROGAS  POR CONSUMO DE DROGAS  \
# 381                   668.0                  163.0
# 382                     9.0                    5.0
# 383                     7.0                    3.0
# 384                    18.0                    4.0
# 385                    27.0                    5.0
#
#      PROPIEDAD INTELECTUAL E INDUSTRIAL  INFRACCIONES ALIMENTARIAS
# 381                               217.0                      227.0
# 382                                13.0                       36.0
# 383                                 0.0                        0.0
# 384                                 1.0                        2.0
# 385                                27.0                       16.0

# %%
# Guardar el DataFrame resultante en un archivo CSV 
df_ind_criminalidad_Madrid.to_csv('C:/Users/Lenovo/Documents/Master BD/TFM/IND. CRIMINALIDAD/df_ind_criminalidad_Madrid_2023_2024.csv', index=False)

# %%
import pandas as pd

# Ruta del archivo CSV
file_path = 'C:/Users/Lenovo/Documents/Master BD/TFM/Indices criminalidad nacional por regiones.csv'

# Intentar leer el archivo CSV con diferentes codificaciones y manejar malas líneas
for encoding in ['utf-8', 'latin1', 'ISO-8859-1']:
    try:
        nacional_df = pd.read_csv(file_path, encoding=encoding, on_bad_lines='skip', skiprows=5)
        print(f"Archivo leído exitosamente con la codificación {encoding}")
        break
    except UnicodeDecodeError:
        print(f"Error de codificación con {encoding}")
    except pd.errors.ParserError as e:
        print(f"Error de parsing con {encoding}: {e}")

# Verificar el DataFrame resultante
print(nacional_df.head(20))
# Out:
# Error de codificación con utf-8
# Archivo leído exitosamente con la codificación latin1
#                                            Unnamed: 0 enero-marzo 2023  \
# 0                                      TOTAL NACIONAL              NaN
# 1                        I. CRIMINALIDAD CONVENCIONAL         480101.0
# 2       1. Homicidios dolosos y asesinatos consumados             85.0
# 3       2. Homicidios dolosos y asesinatos en grad...            275.0
# 4       3. Delitos graves y menos graves de lesion...           5687.0
# 5                                        4. Secuestro             32.0
# 6                5. Delitos contra la libertad sexual           4293.0
# 7                5.1.-Agresión sexual con penetración           1020.0
# 8       5.2.-Resto de delitos contra la libertad s...           3273.0
# 9               6. Robos con violencia e intimidación          15378.0
# 10                7.1.-Robos con fuerza en domicilios          21608.0
# 11                                          8. Hurtos         163463.0
# 12                      9. Sustracciones de vehículos           7845.0
# 13                              10. Tráfico de drogas           4927.0
# 14             11. Resto de criminalidad convencional         246022.0
# 15      II. CIBERCRIMINALIDAD (infracciones penale...         107826.0
# 16                           12.-Estafas informáticas          96482.0
# 17                             13.-Otros ciberdelitos          11344.0
# 18                    III. TOTAL INFRACCIONES PENALES         587927.0
# 19                                          ANDALUCÍA              NaN
#
#    enero-marzo 2024  Variación % 2024/2023  Unnamed: 4
# 0               NaN                    NaN         NaN
# 1          484467.0                    0.9         NaN
# 2              92.0                    8.2         NaN
# 3             266.0                   -3.3         NaN
# 4            6242.0                    9.8         NaN
# 5              28.0                  -12.5         NaN
# 6            4568.0                    6.4         NaN
# 7            1138.0                   11.6         NaN
# 8            3430.0                    4.8         NaN
# 9           15020.0                   -2.3         NaN
# 10          20872.0                   -3.4         NaN
# 11         156967.0                   -4.0         NaN
# 12           8031.0                    2.4         NaN
# 13           5045.0                    2.4         NaN
# 14         257587.0                    4.7         NaN
# 15         122428.0                   13.5         NaN
# 16         110268.0                   14.3         NaN
# 17          12160.0                    7.2         NaN
# 18         606895.0                    3.2         NaN
# 19              NaN                    NaN         NaN

# %%
sevilla_df = pd.read_csv('C:/Users/Lenovo/Documents/Master BD/TFM/en_sevilla_se_han_cometido_53.810_infracciones_penales_hasta_el_trimestre_4_de_2023.csv')

barcelona_df = pd.read_excel('C:/Users/Lenovo/Documents/Master BD/TFM/DATOS CRIMINALIDAD POR DISTRITOS BARCELONA.xlsx')
