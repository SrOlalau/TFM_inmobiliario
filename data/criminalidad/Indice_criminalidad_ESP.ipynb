# %%
import pandas as pd

file_path = r'C:\Users\Lenovo\Documents\Master BD\TFM\IND. CRIMINALIDAD\Ind_criminalidad_ESP.csv'

# Leer el archivo, ignorando las líneas con un número incorrecto de columnas
def custom_csv_reader(file_path):
    data = []
    with open(file_path, 'r', encoding='latin1') as file:  # Agregué 'encoding'
        for i, line in enumerate(file):
            # Saltar las primeras líneas de metadatos
            if i < 5:
                continue
            columns = line.split(',')
            # Solo incluir filas con el número correcto de columnas (5 en este caso)
            if len(columns) == 5:
                data.append(columns)
    return pd.DataFrame(data, columns=["Region", "Periodo_2023", "Periodo_2024", "Variación %", "Extra"])

df = custom_csv_reader(file_path)
df.head(50)
# Out:
#                                                Region      Periodo_2023  \
# 0                                                      enero-marzo 2023
# 1                        I. CRIMINALIDAD CONVENCIONAL           79661.0
# 2       1. Homicidios dolosos y asesinatos consumados              22.0
# 3       2. Homicidios dolosos y asesinatos en grad...              63.0
# 4       3. Delitos graves y menos graves de lesion...            1072.0
# 5                                        4. Secuestro              10.0
# 6                5. Delitos contra la libertad sexual             716.0
# 7              5.1.-AgresiÃ³n sexual con penetraciÃ³n             128.0
# 8       5.2.-Resto de delitos contra la libertad s...             588.0
# 9              6. Robos con violencia e intimidaciÃ³n            1750.0
# 10                7.1.-Robos con fuerza en domicilios            3333.0
# 11                                          8. Hurtos           22998.0
# 12                     9. Sustracciones de vehÃ­culos            1347.0
# 13                             10. TrÃ¡fico de drogas            1124.0
# 14             11. Resto de criminalidad convencional           45582.0
# 15      II. CIBERCRIMINALIDAD (infracciones penale...           17745.0
# 16                          12.-Estafas informÃ¡ticas           15705.0
# 17                             13.-Otros ciberdelitos            2040.0
# 18                    III. TOTAL INFRACCIONES PENALES           97406.0
# 19                       I. CRIMINALIDAD CONVENCIONAL            6556.0
# 20      1. Homicidios dolosos y asesinatos consumados               2.0
# 21      2. Homicidios dolosos y asesinatos en grad...               7.0
# 22      3. Delitos graves y menos graves de lesion...             117.0
# 23                                       4. Secuestro               1.0
# 24               5. Delitos contra la libertad sexual              73.0
# 25             5.1.-AgresiÃ³n sexual con penetraciÃ³n              13.0
# 26      5.2.-Resto de delitos contra la libertad s...              60.0
# 27             6. Robos con violencia e intimidaciÃ³n             129.0
# 28                7.1.-Robos con fuerza en domicilios             397.0
# 29                                          8. Hurtos            1398.0
# 30                     9. Sustracciones de vehÃ­culos              89.0
# 31                             10. TrÃ¡fico de drogas             112.0
# 32             11. Resto de criminalidad convencional            4125.0
# 33      II. CIBERCRIMINALIDAD (infracciones penale...            1013.0
# 34                          12.-Estafas informÃ¡ticas             899.0
# 35                             13.-Otros ciberdelitos             114.0
# 36                    III. TOTAL INFRACCIONES PENALES            7569.0
# 37                       I. CRIMINALIDAD CONVENCIONAL             232.0
# 38      1. Homicidios dolosos y asesinatos consumados               0.0
# 39      2. Homicidios dolosos y asesinatos en grad...               0.0
# 40      3. Delitos graves y menos graves de lesion...               2.0
# 41                                       4. Secuestro               0.0
# 42               5. Delitos contra la libertad sexual               2.0
# 43             5.1.-AgresiÃ³n sexual con penetraciÃ³n               0.0
# 44      5.2.-Resto de delitos contra la libertad s...               2.0
# 45             6. Robos con violencia e intimidaciÃ³n               3.0
# 46                7.1.-Robos con fuerza en domicilios              13.0
# 47                                          8. Hurtos              42.0
# 48                     9. Sustracciones de vehÃ­culos               1.0
# 49                             10. TrÃ¡fico de drogas               6.0
#
#         Periodo_2024             Variación % Extra
# 0   enero-marzo 2024  VariaciÃ³n % 2024/2023    \n
# 1            77809.0                    -2.3    \n
# 2               27.0                    22.7    \n
# 3               48.0                   -23.8    \n
# 4             1171.0                     9.2    \n
# 5                9.0                   -10.0    \n
# 6              694.0                    -3.1    \n
# 7              119.0                    -7.0    \n
# 8              575.0                    -2.2    \n
# 9             1818.0                     3.9    \n
# 10            3297.0                    -1.1    \n
# 11           21392.0                    -7.0    \n
# 12            1526.0                    13.3    \n
# 13            1047.0                    -6.9    \n
# 14           45292.0                    -0.6    \n
# 15           21604.0                    21.7    \n
# 16           19064.0                    21.4    \n
# 17            2540.0                    24.5    \n
# 18           99413.0                     2.1    \n
# 19            6652.0                     1.5    \n
# 20               6.0                   200.0    \n
# 21               1.0                   -85.7    \n
# 22             125.0                     6.8    \n
# 23               1.0                     0.0    \n
# 24              80.0                     9.6    \n
# 25              19.0                    46.2    \n
# 26              61.0                     1.7    \n
# 27             157.0                    21.7    \n
# 28             367.0                    -7.6    \n
# 29            1463.0                     4.6    \n
# 30              82.0                    -7.9    \n
# 31             124.0                    10.7    \n
# 32            4150.0                     0.6    \n
# 33            1420.0                    40.2    \n
# 34            1260.0                    40.2    \n
# 35             160.0                    40.4    \n
# 36            8072.0                     6.6    \n
# 37             225.0                    -3.0    \n
# 38               0.0                     0.0    \n
# 39               0.0                     0.0    \n
# 40               1.0                   -50.0    \n
# 41               0.0                     0.0    \n
# 42               1.0                   -50.0    \n
# 43               0.0                     0.0    \n
# 44               1.0                   -50.0    \n
# 45               2.0                   -33.3    \n
# 46              14.0                     7.7    \n
# 47              66.0                    57.1    \n
# 48               3.0                   200.0    \n
# 49               3.0                   -50.0    \n

# %%
def custom_csv_reader(file_path):
    data = []
    region = None
    with open(file_path, 'r', encoding='latin1') as file:
        for i, line in enumerate(file):
            if i < 5:  # Saltar las primeras 5 líneas de metadatos
                continue
            columns = line.split(',')
            
            # Si la línea tiene una sola columna, asumimos que es un nombre de región
            if len(columns) == 2:
                region = columns[0].strip()
                continue
            
            
            # Añadir el nombre de la región como primera columna
            if region:
                columns.insert(0, region)
                data.append(columns)
    
    # Crear el DataFrame sin limitar el número de columnas
    df = pd.DataFrame(data)
    return df

df = custom_csv_reader(file_path)

# Mostrar algunas filas del DataFrame para verificar
df.head(30)
# Out:
#                         0                                                  1  \
# 0              ANDALUCÃA                       I. CRIMINALIDAD CONVENCIONAL
# 1              ANDALUCÃA      1. Homicidios dolosos y asesinatos consumados
# 2              ANDALUCÃA      2. Homicidios dolosos y asesinatos en grad...
# 3              ANDALUCÃA      3. Delitos graves y menos graves de lesion...
# 4              ANDALUCÃA                                       4. Secuestro
# 5              ANDALUCÃA               5. Delitos contra la libertad sexual
# 6              ANDALUCÃA             5.1.-AgresiÃ³n sexual con penetraciÃ³n
# 7              ANDALUCÃA      5.2.-Resto de delitos contra la libertad s...
# 8              ANDALUCÃA             6. Robos con violencia e intimidaciÃ³n
# 9              ANDALUCÃA                  7. Robos con fuerza en domicilios
# 10             ANDALUCÃA                7.1.-Robos con fuerza en domicilios
# 11             ANDALUCÃA                                          8. Hurtos
# 12             ANDALUCÃA                     9. Sustracciones de vehÃ­culos
# 13             ANDALUCÃA                             10. TrÃ¡fico de drogas
# 14             ANDALUCÃA             11. Resto de criminalidad convencional
# 15             ANDALUCÃA      II. CIBERCRIMINALIDAD (infracciones penale...
# 16             ANDALUCÃA                          12.-Estafas informÃ¡ticas
# 17             ANDALUCÃA                             13.-Otros ciberdelitos
# 18             ANDALUCÃA                    III. TOTAL INFRACCIONES PENALES
# 19  Provincia de ALMERÃA                       I. CRIMINALIDAD CONVENCIONAL
# 20  Provincia de ALMERÃA      1. Homicidios dolosos y asesinatos consumados
# 21  Provincia de ALMERÃA      2. Homicidios dolosos y asesinatos en grad...
# 22  Provincia de ALMERÃA      3. Delitos graves y menos graves de lesion...
# 23  Provincia de ALMERÃA                                       4. Secuestro
# 24  Provincia de ALMERÃA               5. Delitos contra la libertad sexual
# 25  Provincia de ALMERÃA             5.1.-AgresiÃ³n sexual con penetraciÃ³n
# 26  Provincia de ALMERÃA      5.2.-Resto de delitos contra la libertad s...
# 27  Provincia de ALMERÃA             6. Robos con violencia e intimidaciÃ³n
# 28  Provincia de ALMERÃA                  7. Robos con fuerza en domicilios
# 29  Provincia de ALMERÃA                7.1.-Robos con fuerza en domicilios
#
#                                           2        3       4     5     6
# 0                                   79661.0  77809.0    -2.3    \n  None
# 1                                      22.0     27.0    22.7    \n  None
# 2                                      63.0     48.0   -23.8    \n  None
# 3                                    1072.0   1171.0     9.2    \n  None
# 4                                      10.0      9.0   -10.0    \n  None
# 5                                     716.0    694.0    -3.1    \n  None
# 6                                     128.0    119.0    -7.0    \n  None
# 7                                     588.0    575.0    -2.2    \n  None
# 8                                    1750.0   1818.0     3.9    \n  None
# 9    establecimientos y otras instalaciones   4977.0  4785.0  -3.9    \n
# 10                                   3333.0   3297.0    -1.1    \n  None
# 11                                  22998.0  21392.0    -7.0    \n  None
# 12                                   1347.0   1526.0    13.3    \n  None
# 13                                   1124.0   1047.0    -6.9    \n  None
# 14                                  45582.0  45292.0    -0.6    \n  None
# 15                                  17745.0  21604.0    21.7    \n  None
# 16                                  15705.0  19064.0    21.4    \n  None
# 17                                   2040.0   2540.0    24.5    \n  None
# 18                                  97406.0  99413.0     2.1    \n  None
# 19                                   6556.0   6652.0     1.5    \n  None
# 20                                      2.0      6.0   200.0    \n  None
# 21                                      7.0      1.0   -85.7    \n  None
# 22                                    117.0    125.0     6.8    \n  None
# 23                                      1.0      1.0     0.0    \n  None
# 24                                     73.0     80.0     9.6    \n  None
# 25                                     13.0     19.0    46.2    \n  None
# 26                                     60.0     61.0     1.7    \n  None
# 27                                    129.0    157.0    21.7    \n  None
# 28   establecimientos y otras instalaciones    503.0   463.0  -8.0    \n
# 29                                    397.0    367.0    -7.6    \n  None

# %%
import pandas as pd

file_path = r'C:\Users\Lenovo\Documents\Master BD\TFM\IND. CRIMINALIDAD\Ind_criminalidad_ESP.csv'

def custom_csv_reader(file_path):
    data = []
    region = None
    with open(file_path, 'r', encoding='latin1') as file:
        for i, line in enumerate(file):
            if i < 5:  # Saltar las primeras 5 líneas de metadatos
                continue
            columns = line.split(',')
            
            # Si la línea tiene una sola columna, asumimos que es un nombre de región
            if len(columns) == 2:
                region = columns[0].strip()
                continue
            
            # Añadir el nombre de la región como primera columna
            if region:
                columns.insert(0, region)
                data.append(columns)
    
    # Crear el DataFrame sin limitar el número de columnas
    df = pd.DataFrame(data)
    return df

df = custom_csv_reader(file_path)

# Verificar las regiones
unique_regions = df[0].unique()
print("Regiones detectadas:", unique_regions)

# Mostrar algunas filas del DataFrame para verificar
df.head(20)
# Out:
# Regiones detectadas: ['ANDALUCÃ\x8dA' 'Provincia de ALMERÃ\x8dA' '04003 Adra'
#  '04013 AlmerÃ\xada' '04902 Ejido (El)' '04053 HuÃ©rcal-Overa'
#  '04066 NÃ\xadjar' '04079 Roquetas de Mar' '04102 VÃ\xadcar'
#  'Provincia de CÃ\x81DIZ' '11004 Algeciras' '11006 Arcos de la Frontera'
#  '11007 Barbate' '11008 Barrios (Los)' '11012 CÃ¡diz'
#  '11015 Chiclana de la Frontera' '11014 Conil de la Frontera'
#  '11020 Jerez de la Frontera' '11022 LÃ\xadnea de la ConcepciÃ³n (La)'
#  '11027 Puerto de Santa MarÃ\xada (El)' '11028 Puerto Real' '11030 Rota'
#  '11031 San Fernando' '11033 San Roque' '11032 SanlÃºcar de Barrameda'
#  'Provincia de CÃ\x93RDOBA' '14013 Cabra' '14021 CÃ³rdoba' '14038 Lucena'
#  '14042 Montilla' '14049 Palma del RÃ\xado' '14055 Priego de CÃ³rdoba'
#  '14056 Puente Genil' 'Provincia de GRANADA' '18017 AlmuÃ±Ã©car'
#  '18021 Armilla' '18022 Atarfe' '18023 Baza' '18905 Gabias (Las)'
#  '18087 Granada' '18122 Loja' '18127 Maracena' '18140 Motril'
#  'Provincia de HUELVA' '21002 Aljaraque' '21005 Almonte' '21010 Ayamonte'
#  '21021 Cartaya' '21041 Huelva' '21042 Isla Cristina' '21044 Lepe'
#  '21050 Moguer' 'Provincia de JAÃ\x89N' '23002 AlcalÃ¡ la Real'
#  '23005 AndÃºjar' '23050 JaÃ©n' '23055 Linares' '23060 Martos'
#  '23092 Ã\x9abeda' 'Provincia de MÃ\x81LAGA'
#  '29007 AlhaurÃ\xadn de la Torre' '29008 AlhaurÃ\xadn el Grande'
#  '29015 Antequera' '29025 BenalmÃ¡dena' '29038 CÃ¡rtama' '29042 CoÃ\xadn'
#  '29051 Estepona' '29054 Fuengirola' '29067 MÃ¡laga' '29069 Marbella'
#  '29070 Mijas' '29075 Nerja' '29082 RincÃ³n de la Victoria' '29084 Ronda'
#  '29901 Torremolinos' '29091 Torrox' '29094 VÃ©lez-MÃ¡laga'
#  'Provincia de SEVILLA' '41004 AlcalÃ¡ de GuadaÃ\xadra' '41017 Bormujos'
#  '41021 Camas' '41024 Carmona' '41034 Coria del RÃ\xado'
#  '41038 Dos Hermanas' '41039 Ã\x89cija' '41053 Lebrija'
#  '41058 Mairena del Alcor' '41059 Mairena del Aljarafe'
#  '41065 MorÃ³n de la Frontera' '41069 Palacios y Villafranca (Los)'
#  '41081 Rinconada (La)' '41086 San Juan de Aznalfarache' '41091 Sevilla'
#  '41093 Tomares' '41095 Utrera' 'ARAGÃ\x93N' 'Provincia de HUESCA'
#  '22125 Huesca' 'Provincia de TERUEL' '44216 Teruel'
#  'Provincia de ZARAGOZA' '50297 Zaragoza' 'ASTURIAS (PRINCIPADO DE)'
#  '33004 AvilÃ©s' '33016 CastrillÃ³n' '33024 GijÃ³n' '33031 Langreo'
#  '33037 Mieres' '33044 Oviedo' '33066 Siero' 'BALEARS (ILLES)'
#  'Isla de Formentera' 'Isla  de Eivissa' '07026 Eivissa'
#  '07046 Sant Antoni de Portmany' '07048 Sant Josep de sa Talaia'
#  '07054 Santa EulÃ\xa0ria des Riu' 'Isla de Mallorca' '07003 Alcudia'
#  '07011 CalviÃ' '07027 Inca' '07031 Llucmajor' '07033 Manacor'
#  '07036 MarratxÃ\xad' '07040 Palma' 'Isla de Menorca'
#  '07015 Ciutadella de Menorca' '07032 MaÃ³-MahÃ³n' 'CANARIAS'
#  'Provincia de PALMAS (LAS)' 'Isla de Fuerteventura' '35014 Oliva (La)'
#  '35015 PÃ¡jara' '35017 Puerto del Rosario' 'Isla de Gran Canaria'
#  '35002 AgÃ¼imes' '35006 Arucas' '35009 GÃ¡ldar' '35011 Ingenio'
#  '35012 MogÃ¡n' '35016 Palmas de Gran Canaria (Las)'
#  '35019 San BartolomÃ© de Tirajana' '35022 Santa LucÃ\xada de Tirajana'
#  '35026 Telde' 'Isla de Lanzarote' '35004 Arrecife' '35024 Teguise'
#  '35028 TÃ\xadas' 'Provincia de SANTA CRUZ DE TENERIFE'
#  'Isla de Gomera (La)' 'Isla de Hierro (El)' 'Isla de Palma (La)'
#  '38024 Llanos de Aridane (Los)' 'Isla de Tenerife' '38001 Adeje'
#  '38006 Arona' '38011 Candelaria' '38017 Granadilla de Abona'
#  '38019 GuÃ\xada de Isora' '38020 GÃ¼Ã\xadmar' '38022 Icod de los Vinos'
#  '38026 Orotava (La)' '38028 Puerto de la Cruz' '38031 Realejos (Los)'
#  '38023 San CristÃ³bal de La Laguna' '38035 San Miguel de Abona'
#  '38038 Santa Cruz de Tenerife' '38043 Tacoronte' 'CANTABRIA'
#  '39016 Camargo' '39020 Castro-Urdiales' '39052 PiÃ©lagos'
#  '39075 Santander' '39087 Torrelavega' 'CASTILLA Y LEON'
#  'Provincia de Ã\x81VILA' '05019 Ã\x81vila' 'Provincia de BURGOS'
#  '09018 Aranda de Duero' '09059 Burgos' '09219 Miranda de Ebro'
#  'Provincia de LEÃ\x93N' '24089 LeÃ³n' '24115 Ponferrada'
#  '24142 San AndrÃ©s del Rabanedo' 'Provincia de PALENCIA' '34120 Palencia'
#  'Provincia de SALAMANCA' '37274 Salamanca' 'Provincia de SEGOVIA'
#  '40194 Segovia' 'Provincia de SORIA' '42173 Soria'
#  'Provincia de VALLADOLID' '47010 Arroyo de la Encomienda'
#  '47076 Laguna de Duero' '47085 Medina del Campo' '47186 Valladolid'
#  'Provincia de ZAMORA' '49275 Zamora' 'CASTILLA - LA MANCHA'
#  'Provincia de ALBACETE' '02003 Albacete' '02009 Almansa'
#  '02037 HellÃ\xadn' '02081 Villarrobledo' 'Provincia de CIUDAD REAL'
#  '13005 AlcÃ¡zar de San Juan' '13034 Ciudad Real' '13071 Puertollano'
#  '13082 Tomelloso' '13087 ValdepeÃ±as' 'Provincia de CUENCA'
#  '16078 Cuenca' 'Provincia de GUADALAJARA' '19046 Azuqueca de Henares'
#  '19130 Guadalajara' 'Provincia de TOLEDO' '45081 Illescas'
#  '45161 SeseÃ±a' '45165 Talavera de la Reina' '45168 Toledo'
#  'CATALUÃ\x91A' 'Provincia de BARCELONA' '08015 Badalona'
#  '08252 BarberÃ\xa0 del VallÃ¨s' '08019 Barcelona'
#  '08051 Castellar del VallÃ¨s' '08056 Castelldefels'
#  '08266 Cerdanyola del VallÃ¨s' '08073 CornellÃ\xa0 de Llobregat'
#  '08076 Esparreguera' '08077 Esplugues de Llobregat'
#  '08086 Les Franqueses del VallÃ¨s' '08089 GavÃ' '08096 Granollers'
#  "08101 Hospitalet de Llobregat (L')" '08102 Igualada' '08112 Manlleu'
#  '08113 Manresa' '08114 Martorell' '08118 Masnou (El)' '08121 MatarÃ³'
#  '08123 Molins de Rei' '08124 Mollet del VallÃ¨s'
#  '08125 Montcada i Reixac' '08147 Olesa de Montserrat'
#  '08163 Pineda de Mar' '08169 Prat de Llobregat (El)'
#  '08172 PremiÃ\xa0 de Mar' '08180 Ripollet' '08184 RubÃ\xad'
#  '08187 Sabadell' '08194 Sant AdriÃ\xa0 de BesÃ²s'
#  '08196 Sant Andreu de la Barca' '08200 Sant Boi de Llobregat'
#  '08205 Sant Cugat del VallÃ¨s' '08211 Sant Feliu de Llobregat'
#  '08217 Sant Joan DespÃ\xad' '08221 Sant Just Desvern'
#  '08231 Sant Pere de Ribes' '08238 Sant Quirze del VallÃ¨s'
#  '08263 Sant VicenÃ§ dels Horts' '08245 Santa Coloma de Gramenet'
#  '08260 Santa PerpÃ¨tua de Mogoda' '08270 Sitges' '08279 Terrassa'
#  '08298 Vic' '08301 Viladecans' '08305 Vilafranca del PenedÃ¨s'
#  '08307 Vilanova i la GeltrÃº' '08219 Vilassar de Mar'
#  'Provincia de GIRONA' '17015 Banyoles' '17023 Blanes' '17066 Figueres'
#  '17079 Girona' '17095 Lloret de Mar' '17114 Olot' '17117 Palafrugell'
#  '17152 Roses' '17155 Salt' '17160 Sant Feliu de GuÃ\xadxols'
#  'Provincia de LLEIDA' '25120 Lleida' 'Provincia de TARRAGONA'
#  '43014 Amposta' '43037 Calafell' '43038 Cambrils' '43123 Reus'
#  '43905 Salou' '43148 Tarragona' '43155 Tortosa' '43161 Valls'
#  '43163 Vendrell (El)' '43171 Vila-seca' 'COMUNITAT VALENCIANA'
#  'Provincia de ALICANTE/ALACANT' '03009 Alcoy/Alcoi'
#  "03011 L'AlfÃ\xa0s del Pi" '03014 Alicante/Alacant' '03015 AlmoradÃ\xad'
#  '03018 Altea' '03019 Aspe' '03031 Benidorm' '03047 Calp'
#  '03050 Campello (el)' '03059 Crevillent' '03063 DÃ©nia' '03065 Elche/Elx'
#  '03066 Elda' '03079 Ibi' '03082 JÃ¡vea/XÃ\xa0bia' '03090 Mutxamel'
#  '03093 Novelda' '03099 Orihuela' '03104 Petrer'
#  '03902 Pilar de la Horadada'
#  '03122 San Vicente del Raspeig/Sant Vicent del Raspeig'
#  "03119 Sant Joan d'Alacant" '03121 Santa Pola' '03133 Torrevieja'
#  '03139 Villajoyosa/Vila Joiosa (la)' '03140 Villena'
#  'Provincia de CASTELLÃ\x93N/CASTELLÃ\x93' '12009 Almazora/Almassora'
#  '12027 BenicarlÃ³' '12032 Borriana/Burriana'
#  '12040 CastellÃ³n de la Plana/CastellÃ³ de la Plana' '12084 Onda'
#  "12126 Vall d'UixÃ³ (la)" '12135 Vila-real' '12138 VinarÃ²s'
#  'Provincia de VALENCIA/VALÃ\x88NCIA' '46005 AlaquÃ\xa0s'
#  '46013 Alboraia/Alboraya' '46021 Aldaia' '46022 Alfafar'
#  '46029 AlgemesÃ\xad' '46017 Alzira' '46070 BÃ©tera' '46078 Burjassot'
#  '46083 Carcaixent' '46094 Catarroja' '46105 Cullera' '46131 Gandia'
#  '46147 LlÃ\xadria' '46159 Manises' '46169 Mislata' '46171 Moncada'
#  '46181 Oliva' '46184 Ontinyent' '46186 Paiporta' '46190 Paterna'
#  '46194 Picassent' '46202 Pobla de Vallbona (la)' '46205 PuÃ§ol'
#  '46102 Quart de Poblet' '46213 Requena' '46214 Riba-roja de TÃºria'
#  '46220 Sagunto/Sagunt' '46235 Sueca' '46244 Torrent' '46250 Valencia'
#  '46145 XÃ\xa0tiva' '46110 Xirivella' 'EXTREMADURA' 'Provincia de BADAJOZ'
#  '06011 Almendralejo' '06015 Badajoz' '06044 Don Benito' '06083 MÃ©rida'
#  '06153 Villanueva de la Serena' 'Provincia de CÃ\x81CERES'
#  '10037 CÃ¡ceres' '10148 Plasencia' 'GALICIA'
#  'Provincia de CORUÃ\x91A (A)' '15002 Ames' '15005 Arteixo' '15017 Cambre'
#  '15019 Carballo' '15030 CoruÃ±a (A)' '15031 Culleredo' '15036 Ferrol'
#  '15054 NarÃ³n' '15058 Oleiros' '15073 Ribeira'
#  '15078 Santiago de Compostela' 'Provincia de LUGO' '27028 Lugo'
#  'Provincia de OURENSE' '32054 Ourense' 'Provincia de PONTEVEDRA'
#  '36008 Cangas' '36017 Estrada (A)' '36024 LalÃ\xadn' '36026 MarÃ\xadn'
#  '36042 Ponteareas' '36038 Pontevedra' '36045 Redondela' '36057 Vigo'
#  '36060 VilagarcÃ\xada de Arousa' 'MADRID (COMUNIDAD DE)'
#  '28005 AlcalÃ¡ de Henares' '28006 Alcobendas' '28007 AlcorcÃ³n'
#  '28009 Algete' '28013 Aranjuez' '28014 Arganda del Rey'
#  '28015 Arroyomolinos' '28022 Boadilla del Monte' '28040 Ciempozuelos'
#  '28047 Collado Villalba' '28045 Colmenar Viejo' '28049 Coslada'
#  '28058 Fuenlabrada' '28061 Galapagar' '28065 Getafe' '28074 LeganÃ©s'
#  '28079 Madrid' '28080 Majadahonda' '28084 Mejorada del Campo'
#  '28092 MÃ³stoles' '28096 Navalcarnero' '28104 Paracuellos de Jarama'
#  '28106 Parla' '28113 Pinto' '28115 Pozuelo de AlarcÃ³n'
#  '28123 Rivas-Vaciamadrid' '28127 Rozas de Madrid (Las)'
#  '28130 San Fernando de Henares' '28134 San SebastiÃ¡n de los Reyes'
#  '28132 San MartÃ\xadn de la Vega' '28148 TorrejÃ³n de Ardoz'
#  '28152 Torrelodones' '28184 Tres Cantos' '28161 Valdemoro'
#  '28176 Villanueva de la CaÃ±ada' '28181 Villaviciosa de OdÃ³n'
#  'MURCIA (REGION DE)' '30003 Ã\x81guilas' '30005 Alcantarilla'
#  '30008 Alhama de Murcia' '30009 Archena' '30015 Caravaca de la Cruz'
#  '30016 Cartagena' '30019 Cieza' '30022 Jumilla' '30024 Lorca'
#  '30026 MazarrÃ³n' '30027 Molina de Segura' '30030 Murcia'
#  '30035 San Javier' '30036 San Pedro del Pinatar' '30037 Torre-Pacheco'
#  '30038 Torres de Cotillas (Las)' '30039 Totana' '30041 La UniÃ³n'
#  '30043 Yecla' 'NAVARRA (COMUNIDAD FORAL DE)' '31060 Burlada/Burlata'
#  '31201 Pamplona/IruÃ±a' '31232 Tudela' '31086 Valle de EgÃ¼Ã©s/Eguesibar'
#  'PAÃ\x8dS VASCO' 'Provincia de ARABA/Ã\x81LAVA' '01059 Vitoria-Gasteiz'
#  'Provincia de GIPUZKOA' '20055 Arrasate/MondragÃ³n'
#  '20069 Donostia/San SebastiÃ¡n' '20030 Eibar' '20067 Errenteria'
#  '20040 Hernani' '20045 Irun' '20071 Tolosa' '20079 Zarautz'
#  'Provincia de BIZKAIA' '48013 Barakaldo' '48015 Basauri' '48020 Bilbao'
#  '48027 Durango' '48902 Erandio' '48036 Galdakao' '48044 Getxo'
#  '48054 Leioa' '48078 Portugalete' '48082 Santurtzi' '48084 Sestao'
#  'RIOJA (LA)' '26036 Calahorra' '26089 LogroÃ±o'
#  'CIUDAD AUTÃ\x93NOMA DE CEUTA' 'CIUDAD AUTÃ\x93NOMA DE MELILLA'
#  'EXTRANJERA' 'NACIONAL']
#                         0                                                  1  \
# 0              ANDALUCÃA                       I. CRIMINALIDAD CONVENCIONAL
# 1              ANDALUCÃA      1. Homicidios dolosos y asesinatos consumados
# 2              ANDALUCÃA      2. Homicidios dolosos y asesinatos en grad...
# 3              ANDALUCÃA      3. Delitos graves y menos graves de lesion...
# 4              ANDALUCÃA                                       4. Secuestro
# 5              ANDALUCÃA               5. Delitos contra la libertad sexual
# 6              ANDALUCÃA             5.1.-AgresiÃ³n sexual con penetraciÃ³n
# 7              ANDALUCÃA      5.2.-Resto de delitos contra la libertad s...
# 8              ANDALUCÃA             6. Robos con violencia e intimidaciÃ³n
# 9              ANDALUCÃA                  7. Robos con fuerza en domicilios
# 10             ANDALUCÃA                7.1.-Robos con fuerza en domicilios
# 11             ANDALUCÃA                                          8. Hurtos
# 12             ANDALUCÃA                     9. Sustracciones de vehÃ­culos
# 13             ANDALUCÃA                             10. TrÃ¡fico de drogas
# 14             ANDALUCÃA             11. Resto de criminalidad convencional
# 15             ANDALUCÃA      II. CIBERCRIMINALIDAD (infracciones penale...
# 16             ANDALUCÃA                          12.-Estafas informÃ¡ticas
# 17             ANDALUCÃA                             13.-Otros ciberdelitos
# 18             ANDALUCÃA                    III. TOTAL INFRACCIONES PENALES
# 19  Provincia de ALMERÃA                       I. CRIMINALIDAD CONVENCIONAL
#
#                                           2        3       4     5     6
# 0                                   79661.0  77809.0    -2.3    \n  None
# 1                                      22.0     27.0    22.7    \n  None
# 2                                      63.0     48.0   -23.8    \n  None
# 3                                    1072.0   1171.0     9.2    \n  None
# 4                                      10.0      9.0   -10.0    \n  None
# 5                                     716.0    694.0    -3.1    \n  None
# 6                                     128.0    119.0    -7.0    \n  None
# 7                                     588.0    575.0    -2.2    \n  None
# 8                                    1750.0   1818.0     3.9    \n  None
# 9    establecimientos y otras instalaciones   4977.0  4785.0  -3.9    \n
# 10                                   3333.0   3297.0    -1.1    \n  None
# 11                                  22998.0  21392.0    -7.0    \n  None
# 12                                   1347.0   1526.0    13.3    \n  None
# 13                                   1124.0   1047.0    -6.9    \n  None
# 14                                  45582.0  45292.0    -0.6    \n  None
# 15                                  17745.0  21604.0    21.7    \n  None
# 16                                  15705.0  19064.0    21.4    \n  None
# 17                                   2040.0   2540.0    24.5    \n  None
# 18                                  97406.0  99413.0     2.1    \n  None
# 19                                   6556.0   6652.0     1.5    \n  None

# %%
import pandas as pd
import re

file_path = r'C:\Users\Lenovo\Documents\Master BD\TFM\IND. CRIMINALIDAD\Ind_criminalidad_ESP.csv'

def custom_csv_reader(file_path):
    data = []
    region = None
    with open(file_path, 'r', encoding='latin1') as file:
        for i, line in enumerate(file):
            if i < 5:  # Saltar las primeras 5 líneas de metadatos
                continue
            columns = line.split(',')
            
            # Si la línea tiene una sola columna, asumimos que es un nombre de región
            if len(columns) == 2:
                region = columns[0].strip()
                # Eliminar los números y otros caracteres no deseados
                region = re.sub(r'\d+', '', region)
                region = re.sub(r'[\x00-\x1f\x7f-\x9f\xad]', '', region)  # Remover caracteres especiales
                region = region.strip()
                continue
            
            # Añadir el nombre de la región como primera columna
            if region:
                columns.insert(0, region)
                data.append(columns)
    
    # Crear el DataFrame
    df = pd.DataFrame(data)
    return df

df = custom_csv_reader(file_path)

# Verificar las regiones
unique_regions = df[0].unique()
print("Regiones detectadas:", unique_regions)

# Mostrar algunas filas del DataFrame para verificar
df.head(20)
# Out:
# Regiones detectadas: ['ANDALUCÃA' 'Provincia de ALMERÃA' 'Adra' 'AlmerÃa' 'Ejido (El)'
#  'HuÃ©rcal-Overa' 'NÃjar' 'Roquetas de Mar' 'VÃcar' 'Provincia de CÃDIZ'
#  'Algeciras' 'Arcos de la Frontera' 'Barbate' 'Barrios (Los)' 'CÃ¡diz'
#  'Chiclana de la Frontera' 'Conil de la Frontera' 'Jerez de la Frontera'
#  'LÃnea de la ConcepciÃ³n (La)' 'Puerto de Santa MarÃa (El)' 'Puerto Real'
#  'Rota' 'San Fernando' 'San Roque' 'SanlÃºcar de Barrameda'
#  'Provincia de CÃRDOBA' 'Cabra' 'CÃ³rdoba' 'Lucena' 'Montilla'
#  'Palma del RÃo' 'Priego de CÃ³rdoba' 'Puente Genil'
#  'Provincia de GRANADA' 'AlmuÃ±Ã©car' 'Armilla' 'Atarfe' 'Baza'
#  'Gabias (Las)' 'Granada' 'Loja' 'Maracena' 'Motril' 'Provincia de HUELVA'
#  'Aljaraque' 'Almonte' 'Ayamonte' 'Cartaya' 'Huelva' 'Isla Cristina'
#  'Lepe' 'Moguer' 'Provincia de JAÃN' 'AlcalÃ¡ la Real' 'AndÃºjar' 'JaÃ©n'
#  'Linares' 'Martos' 'Ãbeda' 'Provincia de MÃLAGA' 'AlhaurÃn de la Torre'
#  'AlhaurÃn el Grande' 'Antequera' 'BenalmÃ¡dena' 'CÃ¡rtama' 'CoÃn'
#  'Estepona' 'Fuengirola' 'MÃ¡laga' 'Marbella' 'Mijas' 'Nerja'
#  'RincÃ³n de la Victoria' 'Ronda' 'Torremolinos' 'Torrox' 'VÃ©lez-MÃ¡laga'
#  'Provincia de SEVILLA' 'AlcalÃ¡ de GuadaÃra' 'Bormujos' 'Camas' 'Carmona'
#  'Coria del RÃo' 'Dos Hermanas' 'Ãcija' 'Lebrija' 'Mairena del Alcor'
#  'Mairena del Aljarafe' 'MorÃ³n de la Frontera'
#  'Palacios y Villafranca (Los)' 'Rinconada (La)'
#  'San Juan de Aznalfarache' 'Sevilla' 'Tomares' 'Utrera' 'ARAGÃN'
#  'Provincia de HUESCA' 'Huesca' 'Provincia de TERUEL' 'Teruel'
#  'Provincia de ZARAGOZA' 'Zaragoza' 'ASTURIAS (PRINCIPADO DE)' 'AvilÃ©s'
#  'CastrillÃ³n' 'GijÃ³n' 'Langreo' 'Mieres' 'Oviedo' 'Siero'
#  'BALEARS (ILLES)' 'Isla de Formentera' 'Isla  de Eivissa' 'Eivissa'
#  'Sant Antoni de Portmany' 'Sant Josep de sa Talaia'
#  'Santa EulÃ\xa0ria des Riu' 'Isla de Mallorca' 'Alcudia' 'CalviÃ' 'Inca'
#  'Llucmajor' 'Manacor' 'MarratxÃ' 'Palma' 'Isla de Menorca'
#  'Ciutadella de Menorca' 'MaÃ³-MahÃ³n' 'CANARIAS'
#  'Provincia de PALMAS (LAS)' 'Isla de Fuerteventura' 'Oliva (La)'
#  'PÃ¡jara' 'Puerto del Rosario' 'Isla de Gran Canaria' 'AgÃ¼imes' 'Arucas'
#  'GÃ¡ldar' 'Ingenio' 'MogÃ¡n' 'Palmas de Gran Canaria (Las)'
#  'San BartolomÃ© de Tirajana' 'Santa LucÃa de Tirajana' 'Telde'
#  'Isla de Lanzarote' 'Arrecife' 'Teguise' 'TÃas'
#  'Provincia de SANTA CRUZ DE TENERIFE' 'Isla de Gomera (La)'
#  'Isla de Hierro (El)' 'Isla de Palma (La)' 'Llanos de Aridane (Los)'
#  'Isla de Tenerife' 'Adeje' 'Arona' 'Candelaria' 'Granadilla de Abona'
#  'GuÃa de Isora' 'GÃ¼Ãmar' 'Icod de los Vinos' 'Orotava (La)'
#  'Puerto de la Cruz' 'Realejos (Los)' 'San CristÃ³bal de La Laguna'
#  'San Miguel de Abona' 'Santa Cruz de Tenerife' 'Tacoronte' 'CANTABRIA'
#  'Camargo' 'Castro-Urdiales' 'PiÃ©lagos' 'Santander' 'Torrelavega'
#  'CASTILLA Y LEON' 'Provincia de ÃVILA' 'Ãvila' 'Provincia de BURGOS'
#  'Aranda de Duero' 'Burgos' 'Miranda de Ebro' 'Provincia de LEÃN' 'LeÃ³n'
#  'Ponferrada' 'San AndrÃ©s del Rabanedo' 'Provincia de PALENCIA'
#  'Palencia' 'Provincia de SALAMANCA' 'Salamanca' 'Provincia de SEGOVIA'
#  'Segovia' 'Provincia de SORIA' 'Soria' 'Provincia de VALLADOLID'
#  'Arroyo de la Encomienda' 'Laguna de Duero' 'Medina del Campo'
#  'Valladolid' 'Provincia de ZAMORA' 'Zamora' 'CASTILLA - LA MANCHA'
#  'Provincia de ALBACETE' 'Albacete' 'Almansa' 'HellÃn' 'Villarrobledo'
#  'Provincia de CIUDAD REAL' 'AlcÃ¡zar de San Juan' 'Ciudad Real'
#  'Puertollano' 'Tomelloso' 'ValdepeÃ±as' 'Provincia de CUENCA' 'Cuenca'
#  'Provincia de GUADALAJARA' 'Azuqueca de Henares' 'Guadalajara'
#  'Provincia de TOLEDO' 'Illescas' 'SeseÃ±a' 'Talavera de la Reina'
#  'Toledo' 'CATALUÃA' 'Provincia de BARCELONA' 'Badalona'
#  'BarberÃ\xa0 del VallÃ¨s' 'Barcelona' 'Castellar del VallÃ¨s'
#  'Castelldefels' 'Cerdanyola del VallÃ¨s' 'CornellÃ\xa0 de Llobregat'
#  'Esparreguera' 'Esplugues de Llobregat' 'Les Franqueses del VallÃ¨s'
#  'GavÃ' 'Granollers' "Hospitalet de Llobregat (L')" 'Igualada' 'Manlleu'
#  'Manresa' 'Martorell' 'Masnou (El)' 'MatarÃ³' 'Molins de Rei'
#  'Mollet del VallÃ¨s' 'Montcada i Reixac' 'Olesa de Montserrat'
#  'Pineda de Mar' 'Prat de Llobregat (El)' 'PremiÃ\xa0 de Mar' 'Ripollet'
#  'RubÃ' 'Sabadell' 'Sant AdriÃ\xa0 de BesÃ²s' 'Sant Andreu de la Barca'
#  'Sant Boi de Llobregat' 'Sant Cugat del VallÃ¨s'
#  'Sant Feliu de Llobregat' 'Sant Joan DespÃ' 'Sant Just Desvern'
#  'Sant Pere de Ribes' 'Sant Quirze del VallÃ¨s' 'Sant VicenÃ§ dels Horts'
#  'Santa Coloma de Gramenet' 'Santa PerpÃ¨tua de Mogoda' 'Sitges'
#  'Terrassa' 'Vic' 'Viladecans' 'Vilafranca del PenedÃ¨s'
#  'Vilanova i la GeltrÃº' 'Vilassar de Mar' 'Provincia de GIRONA'
#  'Banyoles' 'Blanes' 'Figueres' 'Girona' 'Lloret de Mar' 'Olot'
#  'Palafrugell' 'Roses' 'Salt' 'Sant Feliu de GuÃxols'
#  'Provincia de LLEIDA' 'Lleida' 'Provincia de TARRAGONA' 'Amposta'
#  'Calafell' 'Cambrils' 'Reus' 'Salou' 'Tarragona' 'Tortosa' 'Valls'
#  'Vendrell (El)' 'Vila-seca' 'COMUNITAT VALENCIANA'
#  'Provincia de ALICANTE/ALACANT' 'Alcoy/Alcoi' "L'AlfÃ\xa0s del Pi"
#  'Alicante/Alacant' 'AlmoradÃ' 'Altea' 'Aspe' 'Benidorm' 'Calp'
#  'Campello (el)' 'Crevillent' 'DÃ©nia' 'Elche/Elx' 'Elda' 'Ibi'
#  'JÃ¡vea/XÃ\xa0bia' 'Mutxamel' 'Novelda' 'Orihuela' 'Petrer'
#  'Pilar de la Horadada' 'San Vicente del Raspeig/Sant Vicent del Raspeig'
#  "Sant Joan d'Alacant" 'Santa Pola' 'Torrevieja'
#  'Villajoyosa/Vila Joiosa (la)' 'Villena'
#  'Provincia de CASTELLÃN/CASTELLÃ' 'Almazora/Almassora' 'BenicarlÃ³'
#  'Borriana/Burriana' 'CastellÃ³n de la Plana/CastellÃ³ de la Plana' 'Onda'
#  "Vall d'UixÃ³ (la)" 'Vila-real' 'VinarÃ²s'
#  'Provincia de VALENCIA/VALÃNCIA' 'AlaquÃ\xa0s' 'Alboraia/Alboraya'
#  'Aldaia' 'Alfafar' 'AlgemesÃ' 'Alzira' 'BÃ©tera' 'Burjassot' 'Carcaixent'
#  'Catarroja' 'Cullera' 'Gandia' 'LlÃria' 'Manises' 'Mislata' 'Moncada'
#  'Oliva' 'Ontinyent' 'Paiporta' 'Paterna' 'Picassent'
#  'Pobla de Vallbona (la)' 'PuÃ§ol' 'Quart de Poblet' 'Requena'
#  'Riba-roja de TÃºria' 'Sagunto/Sagunt' 'Sueca' 'Torrent' 'Valencia'
#  'XÃ\xa0tiva' 'Xirivella' 'EXTREMADURA' 'Provincia de BADAJOZ'
#  'Almendralejo' 'Badajoz' 'Don Benito' 'MÃ©rida' 'Villanueva de la Serena'
#  'Provincia de CÃCERES' 'CÃ¡ceres' 'Plasencia' 'GALICIA'
#  'Provincia de CORUÃA (A)' 'Ames' 'Arteixo' 'Cambre' 'Carballo'
#  'CoruÃ±a (A)' 'Culleredo' 'Ferrol' 'NarÃ³n' 'Oleiros' 'Ribeira'
#  'Santiago de Compostela' 'Provincia de LUGO' 'Lugo'
#  'Provincia de OURENSE' 'Ourense' 'Provincia de PONTEVEDRA' 'Cangas'
#  'Estrada (A)' 'LalÃn' 'MarÃn' 'Ponteareas' 'Pontevedra' 'Redondela'
#  'Vigo' 'VilagarcÃa de Arousa' 'MADRID (COMUNIDAD DE)'
#  'AlcalÃ¡ de Henares' 'Alcobendas' 'AlcorcÃ³n' 'Algete' 'Aranjuez'
#  'Arganda del Rey' 'Arroyomolinos' 'Boadilla del Monte' 'Ciempozuelos'
#  'Collado Villalba' 'Colmenar Viejo' 'Coslada' 'Fuenlabrada' 'Galapagar'
#  'Getafe' 'LeganÃ©s' 'Madrid' 'Majadahonda' 'Mejorada del Campo'
#  'MÃ³stoles' 'Navalcarnero' 'Paracuellos de Jarama' 'Parla' 'Pinto'
#  'Pozuelo de AlarcÃ³n' 'Rivas-Vaciamadrid' 'Rozas de Madrid (Las)'
#  'San Fernando de Henares' 'San SebastiÃ¡n de los Reyes'
#  'San MartÃn de la Vega' 'TorrejÃ³n de Ardoz' 'Torrelodones' 'Tres Cantos'
#  'Valdemoro' 'Villanueva de la CaÃ±ada' 'Villaviciosa de OdÃ³n'
#  'MURCIA (REGION DE)' 'Ãguilas' 'Alcantarilla' 'Alhama de Murcia'
#  'Archena' 'Caravaca de la Cruz' 'Cartagena' 'Cieza' 'Jumilla' 'Lorca'
#  'MazarrÃ³n' 'Molina de Segura' 'Murcia' 'San Javier'
#  'San Pedro del Pinatar' 'Torre-Pacheco' 'Torres de Cotillas (Las)'
#  'Totana' 'La UniÃ³n' 'Yecla' 'NAVARRA (COMUNIDAD FORAL DE)'
#  'Burlada/Burlata' 'Pamplona/IruÃ±a' 'Tudela' 'Valle de EgÃ¼Ã©s/Eguesibar'
#  'PAÃS VASCO' 'Provincia de ARABA/ÃLAVA' 'Vitoria-Gasteiz'
#  'Provincia de GIPUZKOA' 'Arrasate/MondragÃ³n' 'Donostia/San SebastiÃ¡n'
#  'Eibar' 'Errenteria' 'Hernani' 'Irun' 'Tolosa' 'Zarautz'
#  'Provincia de BIZKAIA' 'Barakaldo' 'Basauri' 'Bilbao' 'Durango' 'Erandio'
#  'Galdakao' 'Getxo' 'Leioa' 'Portugalete' 'Santurtzi' 'Sestao'
#  'RIOJA (LA)' 'Calahorra' 'LogroÃ±o' 'CIUDAD AUTÃNOMA DE CEUTA'
#  'CIUDAD AUTÃNOMA DE MELILLA' 'EXTRANJERA' 'NACIONAL']
#                        0                                                  1  \
# 0              ANDALUCÃA                       I. CRIMINALIDAD CONVENCIONAL
# 1              ANDALUCÃA      1. Homicidios dolosos y asesinatos consumados
# 2              ANDALUCÃA      2. Homicidios dolosos y asesinatos en grad...
# 3              ANDALUCÃA      3. Delitos graves y menos graves de lesion...
# 4              ANDALUCÃA                                       4. Secuestro
# 5              ANDALUCÃA               5. Delitos contra la libertad sexual
# 6              ANDALUCÃA             5.1.-AgresiÃ³n sexual con penetraciÃ³n
# 7              ANDALUCÃA      5.2.-Resto de delitos contra la libertad s...
# 8              ANDALUCÃA             6. Robos con violencia e intimidaciÃ³n
# 9              ANDALUCÃA                  7. Robos con fuerza en domicilios
# 10             ANDALUCÃA                7.1.-Robos con fuerza en domicilios
# 11             ANDALUCÃA                                          8. Hurtos
# 12             ANDALUCÃA                     9. Sustracciones de vehÃ­culos
# 13             ANDALUCÃA                             10. TrÃ¡fico de drogas
# 14             ANDALUCÃA             11. Resto de criminalidad convencional
# 15             ANDALUCÃA      II. CIBERCRIMINALIDAD (infracciones penale...
# 16             ANDALUCÃA                          12.-Estafas informÃ¡ticas
# 17             ANDALUCÃA                             13.-Otros ciberdelitos
# 18             ANDALUCÃA                    III. TOTAL INFRACCIONES PENALES
# 19  Provincia de ALMERÃA                       I. CRIMINALIDAD CONVENCIONAL
#
#                                           2        3       4     5     6
# 0                                   79661.0  77809.0    -2.3    \n  None
# 1                                      22.0     27.0    22.7    \n  None
# 2                                      63.0     48.0   -23.8    \n  None
# 3                                    1072.0   1171.0     9.2    \n  None
# 4                                      10.0      9.0   -10.0    \n  None
# 5                                     716.0    694.0    -3.1    \n  None
# 6                                     128.0    119.0    -7.0    \n  None
# 7                                     588.0    575.0    -2.2    \n  None
# 8                                    1750.0   1818.0     3.9    \n  None
# 9    establecimientos y otras instalaciones   4977.0  4785.0  -3.9    \n
# 10                                   3333.0   3297.0    -1.1    \n  None
# 11                                  22998.0  21392.0    -7.0    \n  None
# 12                                   1347.0   1526.0    13.3    \n  None
# 13                                   1124.0   1047.0    -6.9    \n  None
# 14                                  45582.0  45292.0    -0.6    \n  None
# 15                                  17745.0  21604.0    21.7    \n  None
# 16                                  15705.0  19064.0    21.4    \n  None
# 17                                   2040.0   2540.0    24.5    \n  None
# 18                                  97406.0  99413.0     2.1    \n  None
# 19                                   6556.0   6652.0     1.5    \n  None

# %%
import pandas as pd
import re

file_path = r'C:\Users\Lenovo\Documents\Master BD\TFM\IND. CRIMINALIDAD\Ind_criminalidad_ESP.csv'

def custom_csv_reader(file_path):
    data = []
    region = None

    # Mapeo de caracteres incorrectos a correctos
    replacements = {
        "Ã": "I",  # A veces puede ser "I"
        "Ã¡": "a",
        "Ã©": "e",
        "Ã­": "i",
        "Ã³": "o",
        "Ãº": "u",
        "Ã±": "ñ",
        "Â": "",   # Puede eliminarse si es un carácter incorrecto adicional
        "©": "e",
        "º": "o"
    }

    with open(file_path, 'r', encoding='latin1') as file:
        for i, line in enumerate(file):
            if i < 5:  # Saltar las primeras 5 líneas de metadatos
                continue
            columns = line.split(',')
            
            # Si la línea tiene una sola columna, asumimos que es un nombre de región
            if len(columns) == 2:
                region = columns[0].strip()
                # Eliminar los números y otros caracteres no deseados
                region = re.sub(r'\d+', '', region)
                region = re.sub(r'[\x00-\x1f\x7f-\x9f\xad]', '', region).strip()

                # Reemplazar caracteres incorrectos con los correctos
                for wrong_char, correct_char in replacements.items():
                    region = region.replace(wrong_char, correct_char)
                
                region = region.strip()
                continue
            
            # Añadir el nombre de la región como primera columna
            if region:
                columns.insert(0, region)
                data.append(columns)
    
    # Crear el DataFrame
    df = pd.DataFrame(data)
    return df

df = custom_csv_reader(file_path)

# Verificar las regiones
unique_regions = df[0].unique()
print("Regiones detectadas:", unique_regions)

# Mostrar algunas filas del DataFrame para verificar
df.head(20)
# Out:
# Regiones detectadas: ['ANDALUCIA' 'Provincia de ALMERIA' 'Adra' 'AlmerIa' 'Ejido (El)'
#  'HuIercal-Overa' 'NIjar' 'Roquetas de Mar' 'VIcar' 'Provincia de CIDIZ'
#  'Algeciras' 'Arcos de la Frontera' 'Barbate' 'Barrios (Los)' 'CI¡diz'
#  'Chiclana de la Frontera' 'Conil de la Frontera' 'Jerez de la Frontera'
#  'LInea de la ConcepciI³n (La)' 'Puerto de Santa MarIa (El)' 'Puerto Real'
#  'Rota' 'San Fernando' 'San Roque' 'SanlIocar de Barrameda'
#  'Provincia de CIRDOBA' 'Cabra' 'CI³rdoba' 'Lucena' 'Montilla'
#  'Palma del RIo' 'Priego de CI³rdoba' 'Puente Genil'
#  'Provincia de GRANADA' 'AlmuI±Iecar' 'Armilla' 'Atarfe' 'Baza'
#  'Gabias (Las)' 'Granada' 'Loja' 'Maracena' 'Motril' 'Provincia de HUELVA'
#  'Aljaraque' 'Almonte' 'Ayamonte' 'Cartaya' 'Huelva' 'Isla Cristina'
#  'Lepe' 'Moguer' 'Provincia de JAIN' 'AlcalI¡ la Real' 'AndIojar' 'JaIen'
#  'Linares' 'Martos' 'Ibeda' 'Provincia de MILAGA' 'AlhaurIn de la Torre'
#  'AlhaurIn el Grande' 'Antequera' 'BenalmI¡dena' 'CI¡rtama' 'CoIn'
#  'Estepona' 'Fuengirola' 'MI¡laga' 'Marbella' 'Mijas' 'Nerja'
#  'RincI³n de la Victoria' 'Ronda' 'Torremolinos' 'Torrox' 'VIelez-MI¡laga'
#  'Provincia de SEVILLA' 'AlcalI¡ de GuadaIra' 'Bormujos' 'Camas' 'Carmona'
#  'Coria del RIo' 'Dos Hermanas' 'Icija' 'Lebrija' 'Mairena del Alcor'
#  'Mairena del Aljarafe' 'MorI³n de la Frontera'
#  'Palacios y Villafranca (Los)' 'Rinconada (La)'
#  'San Juan de Aznalfarache' 'Sevilla' 'Tomares' 'Utrera' 'ARAGIN'
#  'Provincia de HUESCA' 'Huesca' 'Provincia de TERUEL' 'Teruel'
#  'Provincia de ZARAGOZA' 'Zaragoza' 'ASTURIAS (PRINCIPADO DE)' 'AvilIes'
#  'CastrillI³n' 'GijI³n' 'Langreo' 'Mieres' 'Oviedo' 'Siero'
#  'BALEARS (ILLES)' 'Isla de Formentera' 'Isla  de Eivissa' 'Eivissa'
#  'Sant Antoni de Portmany' 'Sant Josep de sa Talaia'
#  'Santa EulI\xa0ria des Riu' 'Isla de Mallorca' 'Alcudia' 'CalviI' 'Inca'
#  'Llucmajor' 'Manacor' 'MarratxI' 'Palma' 'Isla de Menorca'
#  'Ciutadella de Menorca' 'MaI³-MahI³n' 'CANARIAS'
#  'Provincia de PALMAS (LAS)' 'Isla de Fuerteventura' 'Oliva (La)'
#  'PI¡jara' 'Puerto del Rosario' 'Isla de Gran Canaria' 'AgI¼imes' 'Arucas'
#  'GI¡ldar' 'Ingenio' 'MogI¡n' 'Palmas de Gran Canaria (Las)'
#  'San BartolomIe de Tirajana' 'Santa LucIa de Tirajana' 'Telde'
#  'Isla de Lanzarote' 'Arrecife' 'Teguise' 'TIas'
#  'Provincia de SANTA CRUZ DE TENERIFE' 'Isla de Gomera (La)'
#  'Isla de Hierro (El)' 'Isla de Palma (La)' 'Llanos de Aridane (Los)'
#  'Isla de Tenerife' 'Adeje' 'Arona' 'Candelaria' 'Granadilla de Abona'
#  'GuIa de Isora' 'GI¼Imar' 'Icod de los Vinos' 'Orotava (La)'
#  'Puerto de la Cruz' 'Realejos (Los)' 'San CristI³bal de La Laguna'
#  'San Miguel de Abona' 'Santa Cruz de Tenerife' 'Tacoronte' 'CANTABRIA'
#  'Camargo' 'Castro-Urdiales' 'PiIelagos' 'Santander' 'Torrelavega'
#  'CASTILLA Y LEON' 'Provincia de IVILA' 'Ivila' 'Provincia de BURGOS'
#  'Aranda de Duero' 'Burgos' 'Miranda de Ebro' 'Provincia de LEIN' 'LeI³n'
#  'Ponferrada' 'San AndrIes del Rabanedo' 'Provincia de PALENCIA'
#  'Palencia' 'Provincia de SALAMANCA' 'Salamanca' 'Provincia de SEGOVIA'
#  'Segovia' 'Provincia de SORIA' 'Soria' 'Provincia de VALLADOLID'
#  'Arroyo de la Encomienda' 'Laguna de Duero' 'Medina del Campo'
#  'Valladolid' 'Provincia de ZAMORA' 'Zamora' 'CASTILLA - LA MANCHA'
#  'Provincia de ALBACETE' 'Albacete' 'Almansa' 'HellIn' 'Villarrobledo'
#  'Provincia de CIUDAD REAL' 'AlcI¡zar de San Juan' 'Ciudad Real'
#  'Puertollano' 'Tomelloso' 'ValdepeI±as' 'Provincia de CUENCA' 'Cuenca'
#  'Provincia de GUADALAJARA' 'Azuqueca de Henares' 'Guadalajara'
#  'Provincia de TOLEDO' 'Illescas' 'SeseI±a' 'Talavera de la Reina'
#  'Toledo' 'CATALUIA' 'Provincia de BARCELONA' 'Badalona'
#  'BarberI\xa0 del VallI¨s' 'Barcelona' 'Castellar del VallI¨s'
#  'Castelldefels' 'Cerdanyola del VallI¨s' 'CornellI\xa0 de Llobregat'
#  'Esparreguera' 'Esplugues de Llobregat' 'Les Franqueses del VallI¨s'
#  'GavI' 'Granollers' "Hospitalet de Llobregat (L')" 'Igualada' 'Manlleu'
#  'Manresa' 'Martorell' 'Masnou (El)' 'MatarI³' 'Molins de Rei'
#  'Mollet del VallI¨s' 'Montcada i Reixac' 'Olesa de Montserrat'
#  'Pineda de Mar' 'Prat de Llobregat (El)' 'PremiI\xa0 de Mar' 'Ripollet'
#  'RubI' 'Sabadell' 'Sant AdriI\xa0 de BesI²s' 'Sant Andreu de la Barca'
#  'Sant Boi de Llobregat' 'Sant Cugat del VallI¨s'
#  'Sant Feliu de Llobregat' 'Sant Joan DespI' 'Sant Just Desvern'
#  'Sant Pere de Ribes' 'Sant Quirze del VallI¨s' 'Sant VicenI§ dels Horts'
#  'Santa Coloma de Gramenet' 'Santa PerpI¨tua de Mogoda' 'Sitges'
#  'Terrassa' 'Vic' 'Viladecans' 'Vilafranca del PenedI¨s'
#  'Vilanova i la GeltrIo' 'Vilassar de Mar' 'Provincia de GIRONA'
#  'Banyoles' 'Blanes' 'Figueres' 'Girona' 'Lloret de Mar' 'Olot'
#  'Palafrugell' 'Roses' 'Salt' 'Sant Feliu de GuIxols'
#  'Provincia de LLEIDA' 'Lleida' 'Provincia de TARRAGONA' 'Amposta'
#  'Calafell' 'Cambrils' 'Reus' 'Salou' 'Tarragona' 'Tortosa' 'Valls'
#  'Vendrell (El)' 'Vila-seca' 'COMUNITAT VALENCIANA'
#  'Provincia de ALICANTE/ALACANT' 'Alcoy/Alcoi' "L'AlfI\xa0s del Pi"
#  'Alicante/Alacant' 'AlmoradI' 'Altea' 'Aspe' 'Benidorm' 'Calp'
#  'Campello (el)' 'Crevillent' 'DIenia' 'Elche/Elx' 'Elda' 'Ibi'
#  'JI¡vea/XI\xa0bia' 'Mutxamel' 'Novelda' 'Orihuela' 'Petrer'
#  'Pilar de la Horadada' 'San Vicente del Raspeig/Sant Vicent del Raspeig'
#  "Sant Joan d'Alacant" 'Santa Pola' 'Torrevieja'
#  'Villajoyosa/Vila Joiosa (la)' 'Villena'
#  'Provincia de CASTELLIN/CASTELLI' 'Almazora/Almassora' 'BenicarlI³'
#  'Borriana/Burriana' 'CastellI³n de la Plana/CastellI³ de la Plana' 'Onda'
#  "Vall d'UixI³ (la)" 'Vila-real' 'VinarI²s'
#  'Provincia de VALENCIA/VALINCIA' 'AlaquI\xa0s' 'Alboraia/Alboraya'
#  'Aldaia' 'Alfafar' 'AlgemesI' 'Alzira' 'BIetera' 'Burjassot' 'Carcaixent'
#  'Catarroja' 'Cullera' 'Gandia' 'LlIria' 'Manises' 'Mislata' 'Moncada'
#  'Oliva' 'Ontinyent' 'Paiporta' 'Paterna' 'Picassent'
#  'Pobla de Vallbona (la)' 'PuI§ol' 'Quart de Poblet' 'Requena'
#  'Riba-roja de TIoria' 'Sagunto/Sagunt' 'Sueca' 'Torrent' 'Valencia'
#  'XI\xa0tiva' 'Xirivella' 'EXTREMADURA' 'Provincia de BADAJOZ'
#  'Almendralejo' 'Badajoz' 'Don Benito' 'MIerida' 'Villanueva de la Serena'
#  'Provincia de CICERES' 'CI¡ceres' 'Plasencia' 'GALICIA'
#  'Provincia de CORUIA (A)' 'Ames' 'Arteixo' 'Cambre' 'Carballo'
#  'CoruI±a (A)' 'Culleredo' 'Ferrol' 'NarI³n' 'Oleiros' 'Ribeira'
#  'Santiago de Compostela' 'Provincia de LUGO' 'Lugo'
#  'Provincia de OURENSE' 'Ourense' 'Provincia de PONTEVEDRA' 'Cangas'
#  'Estrada (A)' 'LalIn' 'MarIn' 'Ponteareas' 'Pontevedra' 'Redondela'
#  'Vigo' 'VilagarcIa de Arousa' 'MADRID (COMUNIDAD DE)'
#  'AlcalI¡ de Henares' 'Alcobendas' 'AlcorcI³n' 'Algete' 'Aranjuez'
#  'Arganda del Rey' 'Arroyomolinos' 'Boadilla del Monte' 'Ciempozuelos'
#  'Collado Villalba' 'Colmenar Viejo' 'Coslada' 'Fuenlabrada' 'Galapagar'
#  'Getafe' 'LeganIes' 'Madrid' 'Majadahonda' 'Mejorada del Campo'
#  'MI³stoles' 'Navalcarnero' 'Paracuellos de Jarama' 'Parla' 'Pinto'
#  'Pozuelo de AlarcI³n' 'Rivas-Vaciamadrid' 'Rozas de Madrid (Las)'
#  'San Fernando de Henares' 'San SebastiI¡n de los Reyes'
#  'San MartIn de la Vega' 'TorrejI³n de Ardoz' 'Torrelodones' 'Tres Cantos'
#  'Valdemoro' 'Villanueva de la CaI±ada' 'Villaviciosa de OdI³n'
#  'MURCIA (REGION DE)' 'Iguilas' 'Alcantarilla' 'Alhama de Murcia'
#  'Archena' 'Caravaca de la Cruz' 'Cartagena' 'Cieza' 'Jumilla' 'Lorca'
#  'MazarrI³n' 'Molina de Segura' 'Murcia' 'San Javier'
#  'San Pedro del Pinatar' 'Torre-Pacheco' 'Torres de Cotillas (Las)'
#  'Totana' 'La UniI³n' 'Yecla' 'NAVARRA (COMUNIDAD FORAL DE)'
#  'Burlada/Burlata' 'Pamplona/IruI±a' 'Tudela' 'Valle de EgI¼Ies/Eguesibar'
#  'PAIS VASCO' 'Provincia de ARABA/ILAVA' 'Vitoria-Gasteiz'
#  'Provincia de GIPUZKOA' 'Arrasate/MondragI³n' 'Donostia/San SebastiI¡n'
#  'Eibar' 'Errenteria' 'Hernani' 'Irun' 'Tolosa' 'Zarautz'
#  'Provincia de BIZKAIA' 'Barakaldo' 'Basauri' 'Bilbao' 'Durango' 'Erandio'
#  'Galdakao' 'Getxo' 'Leioa' 'Portugalete' 'Santurtzi' 'Sestao'
#  'RIOJA (LA)' 'Calahorra' 'LogroI±o' 'CIUDAD AUTINOMA DE CEUTA'
#  'CIUDAD AUTINOMA DE MELILLA' 'EXTRANJERA' 'NACIONAL']
#                        0                                                  1  \
# 0              ANDALUCIA                       I. CRIMINALIDAD CONVENCIONAL
# 1              ANDALUCIA      1. Homicidios dolosos y asesinatos consumados
# 2              ANDALUCIA      2. Homicidios dolosos y asesinatos en grad...
# 3              ANDALUCIA      3. Delitos graves y menos graves de lesion...
# 4              ANDALUCIA                                       4. Secuestro
# 5              ANDALUCIA               5. Delitos contra la libertad sexual
# 6              ANDALUCIA             5.1.-AgresiÃ³n sexual con penetraciÃ³n
# 7              ANDALUCIA      5.2.-Resto de delitos contra la libertad s...
# 8              ANDALUCIA             6. Robos con violencia e intimidaciÃ³n
# 9              ANDALUCIA                  7. Robos con fuerza en domicilios
# 10             ANDALUCIA                7.1.-Robos con fuerza en domicilios
# 11             ANDALUCIA                                          8. Hurtos
# 12             ANDALUCIA                     9. Sustracciones de vehÃ­culos
# 13             ANDALUCIA                             10. TrÃ¡fico de drogas
# 14             ANDALUCIA             11. Resto de criminalidad convencional
# 15             ANDALUCIA      II. CIBERCRIMINALIDAD (infracciones penale...
# 16             ANDALUCIA                          12.-Estafas informÃ¡ticas
# 17             ANDALUCIA                             13.-Otros ciberdelitos
# 18             ANDALUCIA                    III. TOTAL INFRACCIONES PENALES
# 19  Provincia de ALMERIA                       I. CRIMINALIDAD CONVENCIONAL
#
#                                           2        3       4     5     6
# 0                                   79661.0  77809.0    -2.3    \n  None
# 1                                      22.0     27.0    22.7    \n  None
# 2                                      63.0     48.0   -23.8    \n  None
# 3                                    1072.0   1171.0     9.2    \n  None
# 4                                      10.0      9.0   -10.0    \n  None
# 5                                     716.0    694.0    -3.1    \n  None
# 6                                     128.0    119.0    -7.0    \n  None
# 7                                     588.0    575.0    -2.2    \n  None
# 8                                    1750.0   1818.0     3.9    \n  None
# 9    establecimientos y otras instalaciones   4977.0  4785.0  -3.9    \n
# 10                                   3333.0   3297.0    -1.1    \n  None
# 11                                  22998.0  21392.0    -7.0    \n  None
# 12                                   1347.0   1526.0    13.3    \n  None
# 13                                   1124.0   1047.0    -6.9    \n  None
# 14                                  45582.0  45292.0    -0.6    \n  None
# 15                                  17745.0  21604.0    21.7    \n  None
# 16                                  15705.0  19064.0    21.4    \n  None
# 17                                   2040.0   2540.0    24.5    \n  None
# 18                                  97406.0  99413.0     2.1    \n  None
# 19                                   6556.0   6652.0     1.5    \n  None

# %%
# Mapeo de correcciones específicas para los nombres de regiones ya detectados
corrections = {
    "ANDALUCIA": "Andalucía",
    "Provincia de ALMERIA": "Provincia de Almería",
    "Adra": "Adra",
    "AlmerIa": "Almería",
    "Ejido (El)": "El Ejido",
    "HuIercal-Overa": "Huércal-Overa",
    "NIjar": "Níjar",
    "Roquetas de Mar": "Roquetas de Mar",
    "VIcar": "Vícar",
    "Provincia de CIDIZ": "Provincia de Cádiz",
    "Algeciras": "Algeciras",
    "Arcos de la Frontera": "Arcos de la Frontera",
    "Barbate": "Barbate",
    "Barrios (Los)": "Los Barrios",
    "CI¡diz": "Cádiz",
    "Chiclana de la Frontera": "Chiclana de la Frontera",
    "Conil de la Frontera": "Conil de la Frontera",
    "Jerez de la Frontera": "Jerez de la Frontera",
    "LInea de la ConcepciI³n (La)": "Línea de la Concepción",
    "Puerto de Santa MarIa (El)": "Puerto de Santa María",
    "Puerto Real": "Puerto Real",
    "Rota": "Rota",
    "San Fernando": "San Fernando",
    "San Roque": "San Roque",
    "SanlIocar de Barrameda": "Sanlúcar de Barrameda",
    "Provincia de CIRDOBA": "Provincia de Córdoba",
    "Cabra": "Cabra",
    "CI³rdoba": "Córdoba",
    "Lucena": "Lucena",
    "Montilla": "Montilla",
    "Palma del RIo": "Palma del Río",
    "Priego de CI³rdoba": "Priego de Córdoba",
    "Puente Genil": "Puente Genil",
    "Provincia de GRANADA": "Provincia de Granada",
    "AlmuI±Iecar": "Almuñécar",
    "Armilla": "Armilla",
    "Atarfe": "Atarfe",
    "Baza": "Baza",
    "Gabias (Las)": "Las Gabias",
    "Granada": "Granada",
    "Loja": "Loja",
    "Maracena": "Maracena",
    "Motril": "Motril",
    "Provincia de HUELVA": "Provincia de Huelva",
    "Aljaraque": "Aljaraque",
    "Almonte": "Almonte",
    "Ayamonte": "Ayamonte",
    "Cartaya": "Cartaya",
    "Huelva": "Huelva",
    "Isla Cristina": "Isla Cristina",
    "Lepe": "Lepe",
    "Moguer": "Moguer",
    "Provincia de JAIN": "Provincia de Jaén",
    "AlcalI¡ la Real": "Alcalá la Real",
    "AndIojar": "Andújar",
    "JaIen": "Jaén",
    "Linares": "Linares",
    "Martos": "Martos",
    "Ibeda": "Úbeda",
    "Provincia de MILAGA": "Provincia de Málaga",
    "AlhaurIn de la Torre": "Alhaurín de la Torre",
    "AlhaurIn el Grande": "Alhaurín el Grande",
    "Antequera": "Antequera",
    "BenalmI¡dena": "Benalmádena",
    "CI¡rtama": "Cártama",
    "CoIn": "Coín",
    "Estepona": "Estepona",
    "Fuengirola": "Fuengirola",
    "MI¡laga": "Málaga",
    "Marbella": "Marbella",
    "Mijas": "Mijas",
    "Nerja": "Nerja",
    "RincI³n de la Victoria": "Rincón de la Victoria",
    "Ronda": "Ronda",
    "Torremolinos": "Torremolinos",
    "Torrox": "Torrox",
    "VIelez-MI¡laga": "Vélez-Málaga",
    "Provincia de SEVILLA": "Provincia de Sevilla",
    "AlcalI¡ de GuadaIra": "Alcalá de Guadaíra",
    "Bormujos": "Bormujos",
    "Camas": "Camas",
    "Carmona": "Carmona",
    "Coria del RIo": "Coria del Río",
    "Dos Hermanas": "Dos Hermanas",
    "Icija": "Écija",
    "Lebrija": "Lebrija",
    "Mairena del Alcor": "Mairena del Alcor",
    "Mairena del Aljarafe": "Mairena del Aljarafe",
    "MorI³n de la Frontera": "Morón de la Frontera",
    "Palacios y Villafranca (Los)": "Los Palacios y Villafranca",
    "Rinconada (La)": "La Rinconada",
    "San Juan de Aznalfarache": "San Juan de Aznalfarache",
    "Sevilla": "Sevilla",
    "Tomares": "Tomares",
    "Utrera": "Utrera",
    "ARAGIN": "Aragón",
    "Provincia de HUESCA": "Provincia de Huesca",
    "Huesca": "Huesca",
    "Provincia de TERUEL": "Provincia de Teruel",
    "Teruel": "Teruel",
    "Provincia de ZARAGOZA": "Provincia de Zaragoza",
    "Zaragoza": "Zaragoza",
    "ASTURIAS (PRINCIPADO DE)": "Asturias (Principado de)",
    "AvilIes": "Avilés",
    "CastrillI³n": "Castrillón",
    "GijI³n": "Gijón",
    "Langreo": "Langreo",
    "Mieres": "Mieres",
    "Oviedo": "Oviedo",
    "Siero": "Siero",
    "BALEARS (ILLES)": "Baleares (Islas)",
    "Isla de Formentera": "Isla de Formentera",
    "Isla  de Eivissa": "Isla de Ibiza",
    "Eivissa": "Ibiza",
    "Sant Antoni de Portmany": "Sant Antoni de Portmany",
    "Sant Josep de sa Talaia": "Sant Josep de sa Talaia",
    "Santa EulI\xa0ria des Riu": "Santa Eulària des Riu",
    "Isla de Mallorca": "Isla de Mallorca",
    "Alcudia": "Alcúdia",
    "CalviI": "Calvià",
    "Inca": "Inca",
    "Llucmajor": "Llucmajor",
    "Manacor": "Manacor",
    "MarratxI": "Marratxí",
    "Palma": "Palma",
    "Isla de Menorca": "Isla de Menorca",
    "Ciutadella de Menorca": "Ciutadella de Menorca",
    "MaI³-MahI³n": "Mahón",
    "CANARIAS": "Canarias",
    "Provincia de PALMAS (LAS)": "Provincia de Las Palmas",
    "Isla de Fuerteventura": "Isla de Fuerteventura",
    "Oliva (La)": "La Oliva",
    "PI¡jara": "Pájara",
    "Puerto del Rosario": "Puerto del Rosario",
    "Isla de Gran Canaria": "Isla de Gran Canaria",
    "AgI¼imes": "Agüimes",
    "Arucas": "Arucas",
    "GI¡ldar": "Gáldar",
    "Ingenio": "Ingenio",
    "MogI¡n": "Mogán",
    "Palmas de Gran Canaria (Las)": "Las Palmas de Gran Canaria",
    "San BartolomIe de Tirajana": "San Bartolomé de Tirajana",
    "Santa LucIa de Tirajana": "Santa Lucía de Tirajana",
    "Telde": "Telde",
    "Isla de Lanzarote": "Isla de Lanzarote",
    "Arrecife": "Arrecife",
    "Teguise": "Teguise",
    "TIas": "Tías",
    "Provincia de SANTA CRUZ DE TENERIFE": "Provincia de Santa Cruz de Tenerife",
    "Isla de Gomera (La)": "La Gomera",
    "Isla de Hierro (El)": "El Hierro",
    "Isla de Palma (La)": "La Palma",
    "Llanos de Aridane (Los)": "Los Llanos de Aridane",
    "Isla de Tenerife": "Isla de Tenerife"
    
    # Agrega aquí más correcciones según sea necesario
}

# Aplicar las correcciones a unique_regions
corrected_regions = [corrections.get(region, region) for region in unique_regions]

# Mostrar las regiones corregidas
print("Regiones corregidas:", corrected_regions)

# Reemplazar las regiones en el DataFrame original
df[0] = df[0].replace(corrections)

# Mostrar algunas filas del DataFrame para verificar las correcciones aplicadas
df.head(20)
# Out:
# Regiones corregidas: ['Andalucía', 'Provincia de Almería', 'Adra', 'Almería', 'El Ejido', 'Huércal-Overa', 'Níjar', 'Roquetas de Mar', 'Vícar', 'Provincia de Cádiz', 'Algeciras', 'Arcos de la Frontera', 'Barbate', 'Los Barrios', 'Cádiz', 'Chiclana de la Frontera', 'Conil de la Frontera', 'Jerez de la Frontera', 'Línea de la Concepción', 'Puerto de Santa María', 'Puerto Real', 'Rota', 'San Fernando', 'San Roque', 'Sanlúcar de Barrameda', 'Provincia de Córdoba', 'Cabra', 'Córdoba', 'Lucena', 'Montilla', 'Palma del Río', 'Priego de Córdoba', 'Puente Genil', 'Provincia de Granada', 'Almuñécar', 'Armilla', 'Atarfe', 'Baza', 'Las Gabias', 'Granada', 'Loja', 'Maracena', 'Motril', 'Provincia de Huelva', 'Aljaraque', 'Almonte', 'Ayamonte', 'Cartaya', 'Huelva', 'Isla Cristina', 'Lepe', 'Moguer', 'Provincia de Jaén', 'Alcalá la Real', 'Andújar', 'Jaén', 'Linares', 'Martos', 'Úbeda', 'Provincia de Málaga', 'Alhaurín de la Torre', 'Alhaurín el Grande', 'Antequera', 'Benalmádena', 'Cártama', 'Coín', 'Estepona', 'Fuengirola', 'Málaga', 'Marbella', 'Mijas', 'Nerja', 'Rincón de la Victoria', 'Ronda', 'Torremolinos', 'Torrox', 'Vélez-Málaga', 'Provincia de Sevilla', 'Alcalá de Guadaíra', 'Bormujos', 'Camas', 'Carmona', 'Coria del Río', 'Dos Hermanas', 'Écija', 'Lebrija', 'Mairena del Alcor', 'Mairena del Aljarafe', 'Morón de la Frontera', 'Los Palacios y Villafranca', 'La Rinconada', 'San Juan de Aznalfarache', 'Sevilla', 'Tomares', 'Utrera', 'Aragón', 'Provincia de Huesca', 'Huesca', 'Provincia de Teruel', 'Teruel', 'Provincia de Zaragoza', 'Zaragoza', 'Asturias (Principado de)', 'Avilés', 'Castrillón', 'Gijón', 'Langreo', 'Mieres', 'Oviedo', 'Siero', 'Baleares (Islas)', 'Isla de Formentera', 'Isla de Ibiza', 'Ibiza', 'Sant Antoni de Portmany', 'Sant Josep de sa Talaia', 'Santa Eulària des Riu', 'Isla de Mallorca', 'Alcúdia', 'Calvià', 'Inca', 'Llucmajor', 'Manacor', 'Marratxí', 'Palma', 'Isla de Menorca', 'Ciutadella de Menorca', 'Mahón', 'Canarias', 'Provincia de Las Palmas', 'Isla de Fuerteventura', 'La Oliva', 'Pájara', 'Puerto del Rosario', 'Isla de Gran Canaria', 'Agüimes', 'Arucas', 'Gáldar', 'Ingenio', 'Mogán', 'Las Palmas de Gran Canaria', 'San Bartolomé de Tirajana', 'Santa Lucía de Tirajana', 'Telde', 'Isla de Lanzarote', 'Arrecife', 'Teguise', 'Tías', 'Provincia de Santa Cruz de Tenerife', 'La Gomera', 'El Hierro', 'La Palma', 'Los Llanos de Aridane', 'Isla de Tenerife', 'Adeje', 'Arona', 'Candelaria', 'Granadilla de Abona', 'GuIa de Isora', 'GI¼Imar', 'Icod de los Vinos', 'Orotava (La)', 'Puerto de la Cruz', 'Realejos (Los)', 'San CristI³bal de La Laguna', 'San Miguel de Abona', 'Santa Cruz de Tenerife', 'Tacoronte', 'CANTABRIA', 'Camargo', 'Castro-Urdiales', 'PiIelagos', 'Santander', 'Torrelavega', 'CASTILLA Y LEON', 'Provincia de IVILA', 'Ivila', 'Provincia de BURGOS', 'Aranda de Duero', 'Burgos', 'Miranda de Ebro', 'Provincia de LEIN', 'LeI³n', 'Ponferrada', 'San AndrIes del Rabanedo', 'Provincia de PALENCIA', 'Palencia', 'Provincia de SALAMANCA', 'Salamanca', 'Provincia de SEGOVIA', 'Segovia', 'Provincia de SORIA', 'Soria', 'Provincia de VALLADOLID', 'Arroyo de la Encomienda', 'Laguna de Duero', 'Medina del Campo', 'Valladolid', 'Provincia de ZAMORA', 'Zamora', 'CASTILLA - LA MANCHA', 'Provincia de ALBACETE', 'Albacete', 'Almansa', 'HellIn', 'Villarrobledo', 'Provincia de CIUDAD REAL', 'AlcI¡zar de San Juan', 'Ciudad Real', 'Puertollano', 'Tomelloso', 'ValdepeI±as', 'Provincia de CUENCA', 'Cuenca', 'Provincia de GUADALAJARA', 'Azuqueca de Henares', 'Guadalajara', 'Provincia de TOLEDO', 'Illescas', 'SeseI±a', 'Talavera de la Reina', 'Toledo', 'CATALUIA', 'Provincia de BARCELONA', 'Badalona', 'BarberI\xa0 del VallI¨s', 'Barcelona', 'Castellar del VallI¨s', 'Castelldefels', 'Cerdanyola del VallI¨s', 'CornellI\xa0 de Llobregat', 'Esparreguera', 'Esplugues de Llobregat', 'Les Franqueses del VallI¨s', 'GavI', 'Granollers', "Hospitalet de Llobregat (L')", 'Igualada', 'Manlleu', 'Manresa', 'Martorell', 'Masnou (El)', 'MatarI³', 'Molin ...
#                        0                                                  1  \
# 0              Andalucía                       I. CRIMINALIDAD CONVENCIONAL
# 1              Andalucía      1. Homicidios dolosos y asesinatos consumados
# 2              Andalucía      2. Homicidios dolosos y asesinatos en grad...
# 3              Andalucía      3. Delitos graves y menos graves de lesion...
# 4              Andalucía                                       4. Secuestro
# 5              Andalucía               5. Delitos contra la libertad sexual
# 6              Andalucía             5.1.-AgresiÃ³n sexual con penetraciÃ³n
# 7              Andalucía      5.2.-Resto de delitos contra la libertad s...
# 8              Andalucía             6. Robos con violencia e intimidaciÃ³n
# 9              Andalucía                  7. Robos con fuerza en domicilios
# 10             Andalucía                7.1.-Robos con fuerza en domicilios
# 11             Andalucía                                          8. Hurtos
# 12             Andalucía                     9. Sustracciones de vehÃ­culos
# 13             Andalucía                             10. TrÃ¡fico de drogas
# 14             Andalucía             11. Resto de criminalidad convencional
# 15             Andalucía      II. CIBERCRIMINALIDAD (infracciones penale...
# 16             Andalucía                          12.-Estafas informÃ¡ticas
# 17             Andalucía                             13.-Otros ciberdelitos
# 18             Andalucía                    III. TOTAL INFRACCIONES PENALES
# 19  Provincia de Almería                       I. CRIMINALIDAD CONVENCIONAL
#
#                                           2        3       4     5     6
# 0                                   79661.0  77809.0    -2.3    \n  None
# 1                                      22.0     27.0    22.7    \n  None
# 2                                      63.0     48.0   -23.8    \n  None
# 3                                    1072.0   1171.0     9.2    \n  None
# 4                                      10.0      9.0   -10.0    \n  None
# 5                                     716.0    694.0    -3.1    \n  None
# 6                                     128.0    119.0    -7.0    \n  None
# 7                                     588.0    575.0    -2.2    \n  None
# 8                                    1750.0   1818.0     3.9    \n  None
# 9    establecimientos y otras instalaciones   4977.0  4785.0  -3.9    \n
# 10                                   3333.0   3297.0    -1.1    \n  None
# 11                                  22998.0  21392.0    -7.0    \n  None
# 12                                   1347.0   1526.0    13.3    \n  None
# 13                                   1124.0   1047.0    -6.9    \n  None
# 14                                  45582.0  45292.0    -0.6    \n  None
# 15                                  17745.0  21604.0    21.7    \n  None
# 16                                  15705.0  19064.0    21.4    \n  None
# 17                                   2040.0   2540.0    24.5    \n  None
# 18                                  97406.0  99413.0     2.1    \n  None
# 19                                   6556.0   6652.0     1.5    \n  None

# %%
df = df.drop(columns=[5, 6])

# %%
# Renombrar las columnas
df.columns = ["Region", "Descripcion", "Periodo_2023", "Periodo_2024", "Porcentaje_variacion"]

# Verificar la estructura del DataFrame con los nuevos nombres de columnas
df.head(20)
# Out:
#                   Region                                        Descripcion  \
# 0              Andalucía                       I. CRIMINALIDAD CONVENCIONAL
# 1              Andalucía      1. Homicidios dolosos y asesinatos consumados
# 2              Andalucía      2. Homicidios dolosos y asesinatos en grad...
# 3              Andalucía      3. Delitos graves y menos graves de lesion...
# 4              Andalucía                                       4. Secuestro
# 5              Andalucía               5. Delitos contra la libertad sexual
# 6              Andalucía             5.1.-AgresiÃ³n sexual con penetraciÃ³n
# 7              Andalucía      5.2.-Resto de delitos contra la libertad s...
# 8              Andalucía             6. Robos con violencia e intimidaciÃ³n
# 9              Andalucía                  7. Robos con fuerza en domicilios
# 10             Andalucía                7.1.-Robos con fuerza en domicilios
# 11             Andalucía                                          8. Hurtos
# 12             Andalucía                     9. Sustracciones de vehÃ­culos
# 13             Andalucía                             10. TrÃ¡fico de drogas
# 14             Andalucía             11. Resto de criminalidad convencional
# 15             Andalucía      II. CIBERCRIMINALIDAD (infracciones penale...
# 16             Andalucía                          12.-Estafas informÃ¡ticas
# 17             Andalucía                             13.-Otros ciberdelitos
# 18             Andalucía                    III. TOTAL INFRACCIONES PENALES
# 19  Provincia de Almería                       I. CRIMINALIDAD CONVENCIONAL
#
#                                Periodo_2023 Periodo_2024 Porcentaje_variacion
# 0                                   79661.0      77809.0                 -2.3
# 1                                      22.0         27.0                 22.7
# 2                                      63.0         48.0                -23.8
# 3                                    1072.0       1171.0                  9.2
# 4                                      10.0          9.0                -10.0
# 5                                     716.0        694.0                 -3.1
# 6                                     128.0        119.0                 -7.0
# 7                                     588.0        575.0                 -2.2
# 8                                    1750.0       1818.0                  3.9
# 9    establecimientos y otras instalaciones       4977.0               4785.0
# 10                                   3333.0       3297.0                 -1.1
# 11                                  22998.0      21392.0                 -7.0
# 12                                   1347.0       1526.0                 13.3
# 13                                   1124.0       1047.0                 -6.9
# 14                                  45582.0      45292.0                 -0.6
# 15                                  17745.0      21604.0                 21.7
# 16                                  15705.0      19064.0                 21.4
# 17                                   2040.0       2540.0                 24.5
# 18                                  97406.0      99413.0                  2.1
# 19                                   6556.0       6652.0                  1.5

# %%
# Crear una copia del DataFrame para trabajar
df_grouped = df.copy()

# %%
# Agrupar las filas de acuerdo a la columna "Region"

df_grouped['Region'] = df_grouped['Region'].where(df_grouped['Region'].ne(df_grouped['Region'].shift()), '')

# Mostrar el  con la agrupación aplicada
df_grouped.head(10)
# Out:
#       Region                                        Descripcion  \
# 0  Andalucía                       I. CRIMINALIDAD CONVENCIONAL
# 1                 1. Homicidios dolosos y asesinatos consumados
# 2                 2. Homicidios dolosos y asesinatos en grad...
# 3                 3. Delitos graves y menos graves de lesion...
# 4                                                  4. Secuestro
# 5                          5. Delitos contra la libertad sexual
# 6                        5.1.-AgresiÃ³n sexual con penetraciÃ³n
# 7                 5.2.-Resto de delitos contra la libertad s...
# 8                        6. Robos con violencia e intimidaciÃ³n
# 9                             7. Robos con fuerza en domicilios
#
#                               Periodo_2023 Periodo_2024 Porcentaje_variacion
# 0                                  79661.0      77809.0                 -2.3
# 1                                     22.0         27.0                 22.7
# 2                                     63.0         48.0                -23.8
# 3                                   1072.0       1171.0                  9.2
# 4                                     10.0          9.0                -10.0
# 5                                    716.0        694.0                 -3.1
# 6                                    128.0        119.0                 -7.0
# 7                                    588.0        575.0                 -2.2
# 8                                   1750.0       1818.0                  3.9
# 9   establecimientos y otras instalaciones       4977.0               4785.0

# %%
import pandas as pd
import numpy as np

# Convertir los valores no numéricos a NaN en las columnas "Periodo_2023" y "Periodo_2024"
df_grouped['Periodo_2023'] = pd.to_numeric(df_grouped['Periodo_2023'], errors='coerce')
df_grouped['Periodo_2024'] = pd.to_numeric(df_grouped['Periodo_2024'], errors='coerce')

# Mostrar el DataFrame después de la conversión
df_grouped.head(50)
# Out:
#                   Region                                        Descripcion  \
# 0              Andalucía                       I. CRIMINALIDAD CONVENCIONAL
# 1                             1. Homicidios dolosos y asesinatos consumados
# 2                             2. Homicidios dolosos y asesinatos en grad...
# 3                             3. Delitos graves y menos graves de lesion...
# 4                                                              4. Secuestro
# 5                                      5. Delitos contra la libertad sexual
# 6                                      5.1.-Agresion sexual con penetracion
# 7                             5.2.-Resto de delitos contra la libertad s...
# 8                                     6. Robos con violencia e intimidacion
# 9                                         7. Robos con fuerza en domicilios
# 10                                      7.1.-Robos con fuerza en domicilios
# 11                                                                8. Hurtos
# 12                                           9. Sustracciones de vehÃ­culos
# 13                                                   10. TrÃ¡fico de drogas
# 14                                   11. Resto de criminalidad convencional
# 16                                                12.-Estafas informÃ¡ticas
# 18                                          III. TOTAL INFRACCIONES PENALES
# 19  Provincia de Almería                       I. CRIMINALIDAD CONVENCIONAL
# 20                            1. Homicidios dolosos y asesinatos consumados
# 21                            2. Homicidios dolosos y asesinatos en grad...
# 22                            3. Delitos graves y menos graves de lesion...
# 23                                                             4. Secuestro
# 24                                     5. Delitos contra la libertad sexual
# 25                                     5.1.-Agresion sexual con penetracion
# 26                            5.2.-Resto de delitos contra la libertad s...
# 27                                    6. Robos con violencia e intimidacion
# 28                                        7. Robos con fuerza en domicilios
# 29                                      7.1.-Robos con fuerza en domicilios
# 30                                                                8. Hurtos
# 31                                           9. Sustracciones de vehÃ­culos
# 32                                                   10. TrÃ¡fico de drogas
# 33                                   11. Resto de criminalidad convencional
# 35                                                12.-Estafas informÃ¡ticas
# 37                                          III. TOTAL INFRACCIONES PENALES
# 38                  Adra                       I. CRIMINALIDAD CONVENCIONAL
# 39                            1. Homicidios dolosos y asesinatos consumados
# 40                            2. Homicidios dolosos y asesinatos en grad...
# 41                            3. Delitos graves y menos graves de lesion...
# 42                                                             4. Secuestro
# 43                                     5. Delitos contra la libertad sexual
# 44                                     5.1.-Agresion sexual con penetracion
# 45                            5.2.-Resto de delitos contra la libertad s...
# 46                                    6. Robos con violencia e intimidacion
# 47                                        7. Robos con fuerza en domicilios
# 48                                      7.1.-Robos con fuerza en domicilios
# 49                                                                8. Hurtos
# 50                                           9. Sustracciones de vehÃ­culos
# 51                                                   10. TrÃ¡fico de drogas
# 52                                   11. Resto de criminalidad convencional
# 54                                                12.-Estafas informÃ¡ticas
#
#     Periodo_2023  Periodo_2024 Porcentaje_variacion
# 0        79661.0       77809.0                 -2.3
# 1           22.0          27.0                 22.7
# 2           63.0          48.0                -23.8
# 3         1072.0        1171.0                  9.2
# 4           10.0           9.0                -10.0
# 5          716.0         694.0                 -3.1
# 6          128.0         119.0                 -7.0
# 7          588.0         575.0                 -2.2
# 8         1750.0        1818.0                  3.9
# 9            NaN        4977.0               4785.0
# 10        3333.0        3297.0                 -1.1
# 11       22998.0       21392.0                 -7.0
# 12        1347.0        1526.0                 13.3
# 13        1124.0        1047.0                 -6.9
# 14       45582.0       45292.0                 -0.6
# 16       15705.0       19064.0                 21.4
# 18       97406.0       99413.0                  2.1
# 19        6556.0        6652.0                  1.5
# 20           2.0           6.0                200.0
# 21           7.0           1.0                -85.7
# 22         117.0         125.0                  6.8
# 23           1.0           1.0                  0.0
# 24          73.0          80.0                  9.6
# 25          13.0          19.0                 46.2
# 26          60.0          61.0                  1.7
# 27         129.0         157.0                 21.7
# 28           NaN         503.0                463.0
# 29         397.0         367.0                 -7.6
# 30        1398.0        1463.0                  4.6
# 31          89.0          82.0                 -7.9
# 32         112.0         124.0                 10.7
# 33        4125.0        4150.0                  0.6
# 35         899.0        1260.0                 40.2
# 37        7569.0        8072.0                  6.6
# 38         232.0         225.0                 -3.0
# 39           0.0           0.0                  0.0
# 40           0.0           0.0                  0.0
# 41           2.0           1.0                -50.0
# 42           0.0           0.0                  0.0
# 43           2.0           1.0                -50.0
# 44           0.0           0.0                  0.0
# 45           2.0           1.0                -50.0
# 46           3.0           2.0                -33.3
# 47           NaN          14.0                 16.0
# 48          13.0          14.0                  7.7
# 49          42.0          66.0                 57.1
# 50           1.0           3.0                200.0
# 51           6.0           3.0                -50.0
# 52         162.0         133.0                -17.9
# 54          19.0          30.0                 57.9

# %%
# Reemplazar "Ã³" por "o" en la columna "Descripcion"
df_grouped['Descripcion'] = df_grouped['Descripcion'].str.replace('Ã³', 'o')

# Mostrar el DataFrame después del reemplazo
df_grouped.head(20)
# Out:
#                   Region                                        Descripcion  \
# 0              Andalucía                       I. CRIMINALIDAD CONVENCIONAL
# 1                             1. Homicidios dolosos y asesinatos consumados
# 2                             2. Homicidios dolosos y asesinatos en grad...
# 3                             3. Delitos graves y menos graves de lesion...
# 4                                                              4. Secuestro
# 5                                      5. Delitos contra la libertad sexual
# 6                                      5.1.-Agresion sexual con penetracion
# 7                             5.2.-Resto de delitos contra la libertad s...
# 8                                     6. Robos con violencia e intimidacion
# 9                                         7. Robos con fuerza en domicilios
# 10                                      7.1.-Robos con fuerza en domicilios
# 11                                                                8. Hurtos
# 12                                           9. Sustracciones de vehÃ­culos
# 13                                                   10. TrÃ¡fico de drogas
# 14                                   11. Resto de criminalidad convencional
# 15                            II. CIBERCRIMINALIDAD (infracciones penale...
# 16                                                12.-Estafas informÃ¡ticas
# 17                                                   13.-Otros ciberdelitos
# 18                                          III. TOTAL INFRACCIONES PENALES
# 19  Provincia de Almería                       I. CRIMINALIDAD CONVENCIONAL
#
#     Periodo_2023  Periodo_2024 Porcentaje_variacion
# 0        79661.0       77809.0                 -2.3
# 1           22.0          27.0                 22.7
# 2           63.0          48.0                -23.8
# 3         1072.0        1171.0                  9.2
# 4           10.0           9.0                -10.0
# 5          716.0         694.0                 -3.1
# 6          128.0         119.0                 -7.0
# 7          588.0         575.0                 -2.2
# 8         1750.0        1818.0                  3.9
# 9            NaN        4977.0               4785.0
# 10        3333.0        3297.0                 -1.1
# 11       22998.0       21392.0                 -7.0
# 12        1347.0        1526.0                 13.3
# 13        1124.0        1047.0                 -6.9
# 14       45582.0       45292.0                 -0.6
# 15       17745.0       21604.0                 21.7
# 16       15705.0       19064.0                 21.4
# 17        2040.0        2540.0                 24.5
# 18       97406.0       99413.0                  2.1
# 19        6556.0        6652.0                  1.5

# %%
# Filtrar las filas que contienen las descripciones específicas utilizando coincidencias parciales
df_grouped = df_grouped[~df_grouped['Descripcion'].str.contains(
    'II. CIBERCRIMINALIDAD|12.-Estafas informáticas|13.-Otros ciberdelitos', case=False, na=False
)]

# Mostrar el DataFrame después de eliminar las filas
df_grouped.head(50)
# Out:
#                   Region                                        Descripcion  \
# 0              Andalucía                       I. CRIMINALIDAD CONVENCIONAL
# 1                             1. Homicidios dolosos y asesinatos consumados
# 2                             2. Homicidios dolosos y asesinatos en grad...
# 3                             3. Delitos graves y menos graves de lesion...
# 4                                                              4. Secuestro
# 5                                      5. Delitos contra la libertad sexual
# 6                                      5.1.-Agresion sexual con penetracion
# 7                             5.2.-Resto de delitos contra la libertad s...
# 8                                     6. Robos con violencia e intimidacion
# 9                                         7. Robos con fuerza en domicilios
# 10                                      7.1.-Robos con fuerza en domicilios
# 11                                                                8. Hurtos
# 12                                           9. Sustracciones de vehÃ­culos
# 13                                                   10. TrÃ¡fico de drogas
# 14                                   11. Resto de criminalidad convencional
# 16                                                12.-Estafas informÃ¡ticas
# 18                                          III. TOTAL INFRACCIONES PENALES
# 19  Provincia de Almería                       I. CRIMINALIDAD CONVENCIONAL
# 20                            1. Homicidios dolosos y asesinatos consumados
# 21                            2. Homicidios dolosos y asesinatos en grad...
# 22                            3. Delitos graves y menos graves de lesion...
# 23                                                             4. Secuestro
# 24                                     5. Delitos contra la libertad sexual
# 25                                     5.1.-Agresion sexual con penetracion
# 26                            5.2.-Resto de delitos contra la libertad s...
# 27                                    6. Robos con violencia e intimidacion
# 28                                        7. Robos con fuerza en domicilios
# 29                                      7.1.-Robos con fuerza en domicilios
# 30                                                                8. Hurtos
# 31                                           9. Sustracciones de vehÃ­culos
# 32                                                   10. TrÃ¡fico de drogas
# 33                                   11. Resto de criminalidad convencional
# 35                                                12.-Estafas informÃ¡ticas
# 37                                          III. TOTAL INFRACCIONES PENALES
# 38                  Adra                       I. CRIMINALIDAD CONVENCIONAL
# 39                            1. Homicidios dolosos y asesinatos consumados
# 40                            2. Homicidios dolosos y asesinatos en grad...
# 41                            3. Delitos graves y menos graves de lesion...
# 42                                                             4. Secuestro
# 43                                     5. Delitos contra la libertad sexual
# 44                                     5.1.-Agresion sexual con penetracion
# 45                            5.2.-Resto de delitos contra la libertad s...
# 46                                    6. Robos con violencia e intimidacion
# 47                                        7. Robos con fuerza en domicilios
# 48                                      7.1.-Robos con fuerza en domicilios
# 49                                                                8. Hurtos
# 50                                           9. Sustracciones de vehÃ­culos
# 51                                                   10. TrÃ¡fico de drogas
# 52                                   11. Resto de criminalidad convencional
# 54                                                12.-Estafas informÃ¡ticas
#
#     Periodo_2023  Periodo_2024 Porcentaje_variacion
# 0        79661.0       77809.0                 -2.3
# 1           22.0          27.0                 22.7
# 2           63.0          48.0                -23.8
# 3         1072.0        1171.0                  9.2
# 4           10.0           9.0                -10.0
# 5          716.0         694.0                 -3.1
# 6          128.0         119.0                 -7.0
# 7          588.0         575.0                 -2.2
# 8         1750.0        1818.0                  3.9
# 9            NaN        4977.0               4785.0
# 10        3333.0        3297.0                 -1.1
# 11       22998.0       21392.0                 -7.0
# 12        1347.0        1526.0                 13.3
# 13        1124.0        1047.0                 -6.9
# 14       45582.0       45292.0                 -0.6
# 16       15705.0       19064.0                 21.4
# 18       97406.0       99413.0                  2.1
# 19        6556.0        6652.0                  1.5
# 20           2.0           6.0                200.0
# 21           7.0           1.0                -85.7
# 22         117.0         125.0                  6.8
# 23           1.0           1.0                  0.0
# 24          73.0          80.0                  9.6
# 25          13.0          19.0                 46.2
# 26          60.0          61.0                  1.7
# 27         129.0         157.0                 21.7
# 28           NaN         503.0                463.0
# 29         397.0         367.0                 -7.6
# 30        1398.0        1463.0                  4.6
# 31          89.0          82.0                 -7.9
# 32         112.0         124.0                 10.7
# 33        4125.0        4150.0                  0.6
# 35         899.0        1260.0                 40.2
# 37        7569.0        8072.0                  6.6
# 38         232.0         225.0                 -3.0
# 39           0.0           0.0                  0.0
# 40           0.0           0.0                  0.0
# 41           2.0           1.0                -50.0
# 42           0.0           0.0                  0.0
# 43           2.0           1.0                -50.0
# 44           0.0           0.0                  0.0
# 45           2.0           1.0                -50.0
# 46           3.0           2.0                -33.3
# 47           NaN          14.0                 16.0
# 48          13.0          14.0                  7.7
# 49          42.0          66.0                 57.1
# 50           1.0           3.0                200.0
# 51           6.0           3.0                -50.0
# 52         162.0         133.0                -17.9
# 54          19.0          30.0                 57.9

# %%
# Supongamos que tu DataFrame se llama df
df_madrid = df_grouped[df_grouped['Region'] == 'Majadahonda']

# Para mostrar el resultado
print(df_madrid)
# Out:
#            Region                       Descripcion  Periodo_2023  \
# 8019  Majadahonda      I. CRIMINALIDAD CONVENCIONAL         877.0
#
#       Periodo_2024 Porcentaje_variacion
# 8019         911.0                  3.9

# %%
#en un archivo CSV en la ruta especificada
df_grouped.to_csv(r'C:\Users\Lenovo\Documents\Master BD\TFM\IND. CRIMINALIDAD\indice_criminalida_ESP.csv', index=False)
